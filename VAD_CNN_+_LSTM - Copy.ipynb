# %% [markdown]
# ### Import Libraries

# %%
import os
import cv2 as cv
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

#from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')
# Out:
# 2025-10-21 01:03:34.642486: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Reduce GPU Memory Usage
# ✅ Enable Memory Growth for TensorFlow

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
print("Available GPUs:", gpu_devices)

# Enable memory growth before TensorFlow initializes the GPU
if gpu_devices:
    try:
        for device in gpu_devices:
            tf.config.experimental.set_memory_growth(device, True)
        print("Memory growth enabled for GPUs.")
    except RuntimeError as e:
        print("Failed to set memory growth:", e)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Memory growth enabled for GPUs.

# %% [markdown]
# ### Set Numpy, Python and Tensorflow seeds to get consistent results on every execution.

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# For visualization, we will pick 20 random categories from the dataset and a random video from each selected category and will visualize the first frame of the selected videos with their associated labels written. This way we'll be able to visualize a subset of the datset.

# %%
ds_name = 'multi_class__short_ds_resized_128'

# Get the names of all classes/categories in the dataset
all_classes_names = os.listdir(ds_name)
num_classes = len(all_classes_names)
    
# Determine the number of rows and columns for the subplot
cols = min(num_classes, 5)  # Limit columns to 5 for better visualization
rows = (num_classes // cols) + (num_classes % cols > 0)
    
# Create a Matplotlib figure with an appropriate size
plt.figure(figsize=(cols * 4, rows * 4))
    
# Iterate through all classes
for counter, selected_class_name in enumerate(all_classes_names, 1):
    # Retrieve the list of all video files in the selected class directory
    video_files_names_list = os.listdir(f'{ds_name}/{selected_class_name}')
        
    if not video_files_names_list:
        continue  # Skip if the class folder is empty
        
    # Randomly select a video file from the list
    selected_video_file_name = random.choice(video_files_names_list)
        
    # Initialize a VideoCapture object to read from the video file
    video_reader = cv.VideoCapture(f'{ds_name}/{selected_class_name}/{selected_video_file_name}')
        
    # Read the first frame of the video file
    success, bgr_frame = video_reader.read()
        
    # Release the VideoCapture object
    video_reader.release()
        
    if not success:
        continue  # Skip if the frame could not be read
            
    # Convert the frame from BGR to RGB format
    rgb_frame = cv.cvtColor(bgr_frame, cv.COLOR_BGR2RGB)
            
    # Write the class name on the video frame
    cv.putText(rgb_frame, selected_class_name, (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
            
    # Display the frame
    plt.subplot(rows, cols, counter)
    plt.imshow(rgb_frame)
    plt.axis('off')
    plt.title(selected_class_name)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 2: Preprocess the Dataset
#
# Next, we will perform some preprocessing on the dataset. First, we will read the video files from the dataset and resize the frames of the videos to a fixed width and height, to reduce the computations and normalized the data to range [0 - 1] by dividing the pixel values with 255, which makes convergence faster while training the network.
#
# But first, Initializing some constants.

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 128, 128

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 7

# Specify the directory containing the UCF50 Dataset.
DATASET_DIR = "multiclass_with_ucf_128"

# Specify the list containing the names of the classes used for training.
CLASSES_LIST = ["accident", "fighting", "fire", "normal_resized"]
#CLASSES_LIST = ["Abnormal", "Normal"]

# %% [markdown]
# **Note:** *The IMAGE_HEIGHT, IMAGE_WIDTH and SQUENCE_LENGTH constants can be increased for better results, although increasing the sequence.*

# %% [markdown]
# ### Create a Function to Extract, Resize & Normalize Frames
#
# We will create a function **`frames_extraction()`** that will create a list containing the resized and normalized frames of a video whose path is passed to it as an argument. The function will read the video file frame by frame, although not all frames are added to the list as we will only need an evenly distributed sequence length of frames.

# %%
def frames_extraction(video_path):
  '''
  This function will extract the required frames from a video after resizing and normalizing them.
  Args:
    video_path: The path of the video in the disk, whose frames are to be extracted.
  Returns:
    frames_list: A list containing the resized and normalized frames of the video.
  '''

  # Declare a list to store video frames.
  frames_list = []

  # Read the video File using the VideoCapture object.
  video_reader = cv.VideoCapture(video_path)

  # Get The total number of frames in the video
  video_frames_count = int(video_reader.get(cv.CAP_PROP_FRAME_COUNT))

  # Calculate the interval after which frames will be added to the list.
  skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

  # Iterate through the Video Frames.
  for frame_counter in range(SEQUENCE_LENGTH):

    # Set the current frame position of the video.
    video_reader.set(cv.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

    # Reading the frame from the video.
    success, frame = video_reader.read()

    # Check if video frame is not successfully read then break the loop
    if not success:
      break

    # Resize the frame to fixed height and width.
    resized_frame = cv.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

    # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
    normalized_frame = resized_frame / 255

    # Append the normalized frame into the frames list
    frames_list.append(normalized_frame)

  # Release the VideoCapture object.
  video_reader.release()

  # Return the frames list.
  return frames_list

# %% [markdown]
# ### Create a Function for Dataset Creation
#
# Now we will create a function **`create_dataset()`** that will iterate through all classes specified in the **`CLASSES_LIST`** constant and will call the function **`frame_extraction()`** on every video file of the selected classes and return the frames (**`features`**), class index(**`labels`**), and video file path (**`video_files_paths`**).

# %%
def create_dataset():
  '''
  This function will extract the data of the selected classes and create the required dataset.

  Returns:

    features:             A List containing the extracted frames of the videos.
    labels:               A list containing the indexes of the classes associated with the videos.
    video_files_paths:    A list containing the paths of the videos in the disk.

  '''


  # Declare Empty Lists to store the features, labels and video file path values.
  features = []
  labels = []
  video_files_paths = []

  # Iterating through all the classes mentioned in the classes list
  for class_index, class_name in enumerate(CLASSES_LIST):

    # Display the name of the class whoose data is being extracted.
    print(f'Extracting Data of Class: {class_name}')

    # Get the list of video files present in the specific class name directory.
    files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

    # Iterate through all the files present in the files list.
    for file_name in files_list:

      # Get the complete video path.
      video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

      # Extract the frames of the video file.
      frames = frames_extraction(video_file_path)

      # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
      # So ignore the videos having frames less than the SEQUENCE_LENGTH.
      if len(frames) == SEQUENCE_LENGTH:

        # Append the data to their respective lists.
        features.append(frames)
        labels.append(class_index)
        video_files_paths.append(video_file_path)

  # Converting the features and labels lists to numpy arrays.
  features = np.asarray(features)
  labels = np.array(labels)

  # Return the frames, class index and video file path.
  return features, labels, video_files_paths

# %% [markdown]
# Now we will utilize the function **`create_dataset()`** created above to extract the data of the selected classes and create the required dataset.

# %%
# Create the dataset
features, labels, video_files_paths = create_dataset()

# Print the counts of features, labels, and video file paths
print(f"Number of features: {len(features)}")
print(f"Number of labels: {len(labels)}")
print(f"Number of video file paths: {len(video_files_paths)}")
# Out:
# Extracting Data of Class: accident
# Extracting Data of Class: fighting
# Extracting Data of Class: fire
# Extracting Data of Class: normal_resized
# Number of features: 397
# Number of labels: 397
# Number of video file paths: 397

# %% [markdown]
# Now we will convert **`labels`** (class indexes) into one-hot encoded vectors.

# %%
# Using Keras's to_categorical method to convert labels into one-hot encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %% [markdown]
# ### Step 3: Split the Data into Train and Test Set
#
# As of now, we have the required **`features`** (a Numpy array containing all the extracted frames of the videos) and **`one_hot_encoded_labels`** (also a Numpy array containing all class labels in one hot encoded format). So now, we will split our data to create training and testing sets. We will also shuffle the dataset before the split to avoid any bias and get splits representing the overall distribution of the data.

# %%
# Split the Data into Train (75%) and Test Set (25%).
#features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)


# Check for NaN or infinite values
if np.any(np.isnan(features)) or np.any(np.isinf(features)):
    print("Features contain NaN or infinite values.")
if np.any(np.isnan(one_hot_encoded_labels)) or np.any(np.isinf(one_hot_encoded_labels)):
    print("Labels contain NaN or infinite values.")

# Reduce the dataset size for troubleshooting (optional)
# features = features[:1000]
# one_hot_encoded_labels = one_hot_encoded_labels[:1000]

# Perform the train-test split
try:
    features_train, features_test, labels_train, labels_test = train_test_split(
        features, one_hot_encoded_labels, test_size=0.25, shuffle=True, random_state=seed_constant,
    )
    print("Train-test split successful.")
except Exception as e:
    print(f"Error during train-test split: {e}")
# Out:
# Train-test split successful.

# %% [markdown]
# ### Step 4: Implement the ConvLSTM Approach
#
# In this step, we will implement the first approach by using a combination of ConvLSTM cells. A ConvLSTM cell is a variant of an LSTM network that contains convolutions operations in the network. It is an LSTM with convolution embedded in the architecture, which makes it capable of identifying spatial features of the data while keeping into account the temporal relation.
#
#
# For video classification, this approach effectively captures the spatial relation in the individual frames and the temporal relation across the different frames. As a result of this convolution structure, the ConvLSTM is capable of taking in 3-dimensional input (**`width, height, num_of_channels`**) whereas a simple LSTM only takes in 1-dimensional input hence an LSTM is incompatible for modeling Spatio-temporal data on its own.

# %% [markdown]
# ### Step 4.1: Construct the Model
#
# To Construct the Model, we will use Keras **`ConvLSTM2D`** recurrent layers. The **`ConvLSTM2D`** layer also takes in the number of filters and kernel size required for applying the convolutional operations. The output of the layer is flattened in the end and is fed to the **`Dense`** layer with softmax activation which outputs the probability each action category.
#
# We will also use **`MaxPooling3D`** layers to reduce the dimensions of frames and avoid unnecessary computations and **`Dropout`** layers to prevent **`overfitting`** the model on the data. The architecture is a simple one and has a small number of trainable parameters. This is because we are only dealing with a small subset of the dataset which does not require a large-scale model.

# %%
def create_convlstm_model():
  '''
  This function will construct the required convlstm model.

  Returns:

    model:  It is the required constructed convlstm model.

  '''

  # We will use a Sequencial model for model construction.
  model = Sequential()

  # Define the Model Architecture

  model.add(ConvLSTM2D(filters = 64, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True, input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 128, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))
  
  model.add(ConvLSTM2D(filters = 128, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 256, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 512, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  #model.add(TimeDistributed(Dropout(0.2)))

  model.add(Flatten())

  model.add(Dense(len(CLASSES_LIST), activation = "softmax"))

  # Display the models summary
  model.summary()

  # Return the constructed convlstm model.
  return model

# %% [markdown]
# Now we will utilize the function **`create_convlstm_model()`** created above, to contruct the required convlstm model.

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message.
print("Model Created Successfully!!")
# Out:
# /mnt/f/Study/Academic/Part 4/Project/Sentinel/TestWithWebCam/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 8, 126, 126,    │       154,624 │
# │                                 │ 64)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 8, 63, 63, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_30             │ (None, 8, 63, 63, 64)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 8, 61, 61, 128) │       885,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 8, 31, 31, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_31             │ (None, 8, 31, 31, 128) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_2 (ConvLSTM2D)      │ (None, 8, 29, 29, 128) │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 8, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_32             │ (None, 8, 15, 15, 128) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)      │ (None, 8, 13, 13, 256) │     3,539,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 8, 7, 7, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_33             │ (None, 8, 7, 7, 256)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_4 (ConvLSTM2D)      │ (None, 8, 5, 5, 512)   │    14,157,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_4 (MaxPooling3D)  │ (None, 8, 3, 3, 512)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │       147,460 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,065,284 (76.54 MB)
#  Trainable params: 20,065,284 (76.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!!

# %% [markdown]
# # **Check Model's Structure**
# Now we will use the **`plot_model()`** function, to check the structure of the constructed model, this is helpful while constructing a complex network and making that the network is created corectly.

# %%
# Plot the structure of the constructed model.
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # **Step 4.2: Compile & Train the Model**
#
# Next, we will add an early stopping callback to prevent `overfitting` and start the training after compiling the model.

# %%
# Create an Instance of Early Stopping Callback
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 2 , shuffle = True, validation_split = 0.1, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/50
# 2025-10-10 20:56:53.500029: I external/local_xla/xla/service/service.cc:163] XLA service 0x7fbb2c4eca90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-10 20:56:53.500454: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2025-10-10 20:56:54.309988: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-10 20:57:00.972322: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:00.972374: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:00.972387: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108221.445321   95470 buffer_comparator.cc:147] Difference at 0: 1.52344, expected -nan
# E0000 00:00:1760108221.445773   95470 buffer_comparator.cc:147] Difference at 1: 1.58398, expected 0
# E0000 00:00:1760108221.445781   95470 buffer_comparator.cc:147] Difference at 2: 1.66113, expected -nan
# E0000 00:00:1760108221.445784   95470 buffer_comparator.cc:147] Difference at 3: 1.61621, expected 0
# E0000 00:00:1760108221.445786   95470 buffer_comparator.cc:147] Difference at 4: 1.55664, expected -nan
# E0000 00:00:1760108221.445790   95470 buffer_comparator.cc:147] Difference at 5: 1.74512, expected 0
# E0000 00:00:1760108221.445792   95470 buffer_comparator.cc:147] Difference at 6: 1.58887, expected -nan
# E0000 00:00:1760108221.445795   95470 buffer_comparator.cc:147] Difference at 7: 1.57324, expected 0
# E0000 00:00:1760108221.445797   95470 buffer_comparator.cc:147] Difference at 8: 1.62012, expected -nan
# E0000 00:00:1760108221.445799   95470 buffer_comparator.cc:147] Difference at 9: 1.76562, expected 0
# 2025-10-10 20:57:01.445814: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,63,63,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}, f16[2,61,61,128]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=0,k13=0,k14=0,k18=0,k23=0} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:01.445823: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:01.445826: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:01.445829: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:01.445831: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:01.445837: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108221.454091   95470 buffer_comparator.cc:147] Difference at 0: 1.52344, expected -nan
# E0000 00:00:1760108221.454138   95470 buffer_comparator.cc:147] Difference at 1: 1.58398, expected 0
# E0000 00:00:1760108221.454145   95470 buffer_comparator.cc:147] Difference at 2: 1.66113, expected -nan
# E0000 00:00:1760108221.454147   95470 buffer_comparator.cc:147] Difference at 3: 1.61621, expected 0
# E0000 00:00:1760108221.454150   95470 buffer_comparator.cc:147] Difference at 4: 1.55664, expected -nan
# E0000 00:00:1760108221.454152   95470 buffer_comparator.cc:147] Difference at 5: 1.74512, expected 0
# E0000 00:00:1760108221.454154   95470 buffer_comparator.cc:147] Difference at 6: 1.58887, expected -nan
# E0000 00:00:1760108221.454157   95470 buffer_comparator.cc:147] Difference at 7: 1.57324, expected 0
# E0000 00:00:1760108221.454159   95470 buffer_comparator.cc:147] Difference at 8: 1.62012, expected -nan
# E0000 00:00:1760108221.454161   95470 buffer_comparator.cc:147] Difference at 9: 1.76562, expected 0
# 2025-10-10 20:57:01.454176: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,63,63,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}, f16[2,61,61,128]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=0,k13=0,k14=0,k18=0,k23=0} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:01.454184: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:01.454187: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:01.454190: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:01.454192: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:01.454198: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108221.462565   95470 buffer_comparator.cc:147] Difference at 0: 1.52344, expected -nan
# E0000 00:00:1760108221.462606   95470 buffer_comparator.cc:147] Difference at 1: 1.58398, expected 0
# E0000 00:00:1760108221.462614   95470 buffer_comparator.cc:147] Difference at 2: 1.66113, expected -nan
# E0000 00:00:1760108221.462617   95470 buffer_comparator.cc:147] Difference at 3: 1.61621, expected 0
# E0000 00:00:1760108221.462619   95470 buffer_comparator.cc:147] Difference at 4: 1.55664, expected -nan
# E0000 00:00:1760108221.462621   95470 buffer_comparator.cc:147] Difference at 5: 1.74512, expected 0
# E0000 00:00:1760108221.462624   95470 buffer_comparator.cc:147] Difference at 6: 1.58887, expected -nan
# E0000 00:00:1760108221.462626   95470 buffer_comparator.cc:147] Difference at 7: 1.57324, expected 0
# E0000 00:00:1760108221.462628   95470 buffer_comparator.cc:147] Difference at 8: 1.62012, expected -nan
# E0000 00:00:1760108221.462631   95470 buffer_comparator.cc:147] Difference at 9: 1.76562, expected 0
# 2025-10-10 20:57:01.462644: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,63,63,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}, f16[2,61,61,128]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=0,k13=0,k14=0,k18=0,k23=0} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-10-10 20:57:01.462652: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:01.462655: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:01.462658: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:01.462660: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:01.462665: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 20:57:01.822521: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:01.827888: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:01.917620: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108222.062629   95470 buffer_comparator.cc:147] Difference at 0: 3.09375, expected -nan
# E0000 00:00:1760108222.062680   95470 buffer_comparator.cc:147] Difference at 1: 3.14844, expected 0
# E0000 00:00:1760108222.062687   95470 buffer_comparator.cc:147] Difference at 2: 3.07031, expected -nan
# E0000 00:00:1760108222.062690   95470 buffer_comparator.cc:147] Difference at 3: 2.98633, expected 0
# E0000 00:00:1760108222.062692   95470 buffer_comparator.cc:147] Difference at 4: 3.02344, expected -nan
# E0000 00:00:1760108222.062695   95470 buffer_comparator.cc:147] Difference at 5: 3.04102, expected 0
# E0000 00:00:1760108222.062697   95470 buffer_comparator.cc:147] Difference at 6: 2.9707, expected -nan
# E0000 00:00:1760108222.062700   95470 buffer_comparator.cc:147] Difference at 7: 3.05469, expected 0
# E0000 00:00:1760108222.062702   95470 buffer_comparator.cc:147] Difference at 8: 3.09375, expected -nan
# E0000 00:00:1760108222.062704   95470 buffer_comparator.cc:147] Difference at 9: 2.99219, expected 0
# 2025-10-10 20:57:02.062717: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,31,31,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}, f16[128]{0}, f16[2,29,29,128]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=5,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-10-10 20:57:02.062727: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:02.062730: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:02.062733: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:02.062735: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:02.062740: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108222.075138   95470 buffer_comparator.cc:147] Difference at 0: 3.09375, expected -nan
# E0000 00:00:1760108222.075179   95470 buffer_comparator.cc:147] Difference at 1: 3.14844, expected 0
# E0000 00:00:1760108222.075186   95470 buffer_comparator.cc:147] Difference at 2: 3.07031, expected -nan
# E0000 00:00:1760108222.075189   95470 buffer_comparator.cc:147] Difference at 3: 2.98633, expected 0
# E0000 00:00:1760108222.075191   95470 buffer_comparator.cc:147] Difference at 4: 3.02344, expected -nan
# E0000 00:00:1760108222.075193   95470 buffer_comparator.cc:147] Difference at 5: 3.04102, expected 0
# E0000 00:00:1760108222.075196   95470 buffer_comparator.cc:147] Difference at 6: 2.9707, expected -nan
# E0000 00:00:1760108222.075198   95470 buffer_comparator.cc:147] Difference at 7: 3.05469, expected 0
# E0000 00:00:1760108222.075200   95470 buffer_comparator.cc:147] Difference at 8: 3.09375, expected -nan
# E0000 00:00:1760108222.075203   95470 buffer_comparator.cc:147] Difference at 9: 2.99219, expected 0
# 2025-10-10 20:57:02.075215: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,31,31,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}, f16[128]{0}, f16[2,29,29,128]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=5,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:02.075223: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:02.075226: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:02.075228: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:02.075230: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:02.075235: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108222.181476   95470 buffer_comparator.cc:147] Difference at 0: 3.09375, expected -nan
# E0000 00:00:1760108222.181529   95470 buffer_comparator.cc:147] Difference at 1: 3.14844, expected 0
# E0000 00:00:1760108222.181537   95470 buffer_comparator.cc:147] Difference at 2: 3.07031, expected -nan
# E0000 00:00:1760108222.181540   95470 buffer_comparator.cc:147] Difference at 3: 2.98633, expected 0
# E0000 00:00:1760108222.181542   95470 buffer_comparator.cc:147] Difference at 4: 3.02344, expected -nan
# E0000 00:00:1760108222.181545   95470 buffer_comparator.cc:147] Difference at 5: 3.04102, expected 0
# E0000 00:00:1760108222.181548   95470 buffer_comparator.cc:147] Difference at 6: 2.9707, expected -nan
# E0000 00:00:1760108222.181550   95470 buffer_comparator.cc:147] Difference at 7: 3.05469, expected 0
# E0000 00:00:1760108222.181553   95470 buffer_comparator.cc:147] Difference at 8: 3.09375, expected -nan
# E0000 00:00:1760108222.181555   95470 buffer_comparator.cc:147] Difference at 9: 2.99219, expected 0
# 2025-10-10 20:57:02.181569: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,31,31,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}, f16[128]{0}, f16[2,29,29,128]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=5,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:02.181578: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:02.181581: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:02.181584: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:02.181586: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:02.181591: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 20:57:02.328259: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0}, f16[256,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:02.347531: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0}, f16[256,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:02.400142: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0}, f16[256,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108222.557652   95470 buffer_comparator.cc:147] Difference at 0: 3.10352, expected -nan
# E0000 00:00:1760108222.557701   95470 buffer_comparator.cc:147] Difference at 1: 3.06836, expected 0
# E0000 00:00:1760108222.557709   95470 buffer_comparator.cc:147] Difference at 2: 3.06836, expected -nan
# E0000 00:00:1760108222.557711   95470 buffer_comparator.cc:147] Difference at 3: 3.00977, expected 0
# E0000 00:00:1760108222.557714   95470 buffer_comparator.cc:147] Difference at 4: 3.18164, expected -nan
# E0000 00:00:1760108222.557716   95470 buffer_comparator.cc:147] Difference at 5: 3.14648, expected 0
# E0000 00:00:1760108222.557718   95470 buffer_comparator.cc:147] Difference at 6: 3.0918, expected -nan
# E0000 00:00:1760108222.557721   95470 buffer_comparator.cc:147] Difference at 7: 3.20508, expected 0
# E0000 00:00:1760108222.557723   95470 buffer_comparator.cc:147] Difference at 8: 3.12695, expected -nan
# E0000 00:00:1760108222.557725   95470 buffer_comparator.cc:147] Difference at 9: 3.02539, expected 0
# 2025-10-10 20:57:02.557743: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,15,15,128]{3,2,1,0}, f16[256,3,3,128]{3,2,1,0}, f16[256]{0}, f16[2,13,13,256]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=8,k13=1,k14=0,k18=0,k23=0} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-10-10 20:57:02.557753: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:02.557756: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:02.557759: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:02.557761: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:02.557769: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108222.564440   95470 buffer_comparator.cc:147] Difference at 0: 3.10352, expected -nan
# E0000 00:00:1760108222.564494   95470 buffer_comparator.cc:147] Difference at 1: 3.06836, expected 0
# E0000 00:00:1760108222.564502   95470 buffer_comparator.cc:147] Difference at 2: 3.06836, expected -nan
# E0000 00:00:1760108222.564505   95470 buffer_comparator.cc:147] Difference at 3: 3.00977, expected 0
# E0000 00:00:1760108222.564507   95470 buffer_comparator.cc:147] Difference at 4: 3.18164, expected -nan
# E0000 00:00:1760108222.564509   95470 buffer_comparator.cc:147] Difference at 5: 3.14648, expected 0
# E0000 00:00:1760108222.564512   95470 buffer_comparator.cc:147] Difference at 6: 3.0918, expected -nan
# E0000 00:00:1760108222.564514   95470 buffer_comparator.cc:147] Difference at 7: 3.20508, expected 0
# E0000 00:00:1760108222.564516   95470 buffer_comparator.cc:147] Difference at 8: 3.12695, expected -nan
# E0000 00:00:1760108222.564518   95470 buffer_comparator.cc:147] Difference at 9: 3.02539, expected 0
# 2025-10-10 20:57:02.564535: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,15,15,128]{3,2,1,0}, f16[256,3,3,128]{3,2,1,0}, f16[256]{0}, f16[2,13,13,256]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=8,k13=1,k14=0,k18=0,k23=0} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:02.564545: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:02.564547: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:02.564550: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:02.564552: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:02.564560: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108222.625678   95470 buffer_comparator.cc:147] Difference at 0: 3.10352, expected -nan
# E0000 00:00:1760108222.625730   95470 buffer_comparator.cc:147] Difference at 1: 3.06836, expected 0
# E0000 00:00:1760108222.625738   95470 buffer_comparator.cc:147] Difference at 2: 3.06836, expected -nan
# E0000 00:00:1760108222.625740   95470 buffer_comparator.cc:147] Difference at 3: 3.00977, expected 0
# E0000 00:00:1760108222.625743   95470 buffer_comparator.cc:147] Difference at 4: 3.18164, expected -nan
# E0000 00:00:1760108222.625746   95470 buffer_comparator.cc:147] Difference at 5: 3.14648, expected 0
# E0000 00:00:1760108222.625749   95470 buffer_comparator.cc:147] Difference at 6: 3.0918, expected -nan
# E0000 00:00:1760108222.625751   95470 buffer_comparator.cc:147] Difference at 7: 3.20508, expected 0
# E0000 00:00:1760108222.625753   95470 buffer_comparator.cc:147] Difference at 8: 3.12695, expected -nan
# E0000 00:00:1760108222.625755   95470 buffer_comparator.cc:147] Difference at 9: 3.02539, expected 0
# 2025-10-10 20:57:02.625769: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,15,15,128]{3,2,1,0}, f16[256,3,3,128]{3,2,1,0}, f16[256]{0}, f16[2,13,13,256]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng9{k2=8,k13=1,k14=0,k18=0,k23=0} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:02.625778: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:02.625780: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:02.625783: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:02.625785: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:02.625790: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 20:57:02.798199: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0}, f16[512,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:02.827973: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0}, f16[512,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:02.906382: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0}, f16[512,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108223.076924   95470 buffer_comparator.cc:147] Difference at 0: 6.14062, expected -nan
# E0000 00:00:1760108223.076986   95470 buffer_comparator.cc:147] Difference at 1: 5.86719, expected 0
# E0000 00:00:1760108223.076995   95470 buffer_comparator.cc:147] Difference at 2: 5.86328, expected -nan
# E0000 00:00:1760108223.076998   95470 buffer_comparator.cc:147] Difference at 3: 5.98047, expected 0
# E0000 00:00:1760108223.077000   95470 buffer_comparator.cc:147] Difference at 4: 6.08984, expected -nan
# E0000 00:00:1760108223.077002   95470 buffer_comparator.cc:147] Difference at 5: 5.94141, expected 0
# E0000 00:00:1760108223.077005   95470 buffer_comparator.cc:147] Difference at 6: 6, expected -nan
# E0000 00:00:1760108223.077007   95470 buffer_comparator.cc:147] Difference at 7: 6.01172, expected 0
# E0000 00:00:1760108223.077010   95470 buffer_comparator.cc:147] Difference at 8: 6.14453, expected -nan
# E0000 00:00:1760108223.077012   95470 buffer_comparator.cc:147] Difference at 9: 6.04688, expected 0
# 2025-10-10 20:57:03.077030: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,7,7,256]{3,2,1,0}, f16[512,3,3,256]{3,2,1,0}, f16[512]{0}, f16[2,5,5,512]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng22{k2=8,k12=6,k13=1,k14=0,k15=0,k17=37,k18=0,k23=0} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-10-10 20:57:03.077041: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:03.077043: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:03.077046: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:03.077048: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:03.077054: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108223.103942   95470 buffer_comparator.cc:147] Difference at 0: 6.14062, expected -nan
# E0000 00:00:1760108223.103992   95470 buffer_comparator.cc:147] Difference at 1: 5.86719, expected 0
# E0000 00:00:1760108223.104008   95470 buffer_comparator.cc:147] Difference at 2: 5.86328, expected -nan
# E0000 00:00:1760108223.104012   95470 buffer_comparator.cc:147] Difference at 3: 5.98047, expected 0
# E0000 00:00:1760108223.104014   95470 buffer_comparator.cc:147] Difference at 4: 6.08984, expected -nan
# E0000 00:00:1760108223.104016   95470 buffer_comparator.cc:147] Difference at 5: 5.94141, expected 0
# E0000 00:00:1760108223.104019   95470 buffer_comparator.cc:147] Difference at 6: 6, expected -nan
# E0000 00:00:1760108223.104021   95470 buffer_comparator.cc:147] Difference at 7: 6.01172, expected 0
# E0000 00:00:1760108223.104023   95470 buffer_comparator.cc:147] Difference at 8: 6.14453, expected -nan
# E0000 00:00:1760108223.104026   95470 buffer_comparator.cc:147] Difference at 9: 6.04688, expected 0
# 2025-10-10 20:57:03.104040: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,7,7,256]{3,2,1,0}, f16[512,3,3,256]{3,2,1,0}, f16[512]{0}, f16[2,5,5,512]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng22{k2=8,k12=6,k13=1,k14=0,k15=0,k17=37,k18=0,k23=0} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:03.104049: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:03.104052: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:03.104055: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:03.104057: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:03.104061: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 20:57:03.175694: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv (f16[2,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,126,126,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:03.365196: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv (f16[2,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,126,126,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-10-10 20:57:03.382284: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv (f16[2,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,126,126,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108223.760380   95470 buffer_comparator.cc:147] Difference at 0: 0.169067, expected -nan
# E0000 00:00:1760108223.760431   95470 buffer_comparator.cc:147] Difference at 1: 0.154053, expected 0
# E0000 00:00:1760108223.760439   95470 buffer_comparator.cc:147] Difference at 2: 0.17395, expected -nan
# E0000 00:00:1760108223.760442   95470 buffer_comparator.cc:147] Difference at 3: 0.17981, expected 0
# E0000 00:00:1760108223.760445   95470 buffer_comparator.cc:147] Difference at 4: 0.137207, expected -nan
# E0000 00:00:1760108223.760447   95470 buffer_comparator.cc:147] Difference at 5: 0.244873, expected 0
# E0000 00:00:1760108223.760450   95470 buffer_comparator.cc:147] Difference at 6: 0.15625, expected -nan
# E0000 00:00:1760108223.760452   95470 buffer_comparator.cc:147] Difference at 7: 0.185425, expected 0
# E0000 00:00:1760108223.760454   95470 buffer_comparator.cc:147] Difference at 8: 0.218628, expected -nan
# E0000 00:00:1760108223.760456   95470 buffer_comparator.cc:147] Difference at 9: 0.172974, expected 0
# 2025-10-10 20:57:03.760471: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,128,128,3]{3,2,1,0}, f16[64,3,3,3]{3,2,1,0}, f16[64]{0}, f16[2,126,126,64]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:03.760481: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:03.760483: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:03.760486: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:03.760488: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:03.760493: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108223.773182   95470 buffer_comparator.cc:147] Difference at 0: 0.169067, expected -nan
# E0000 00:00:1760108223.773228   95470 buffer_comparator.cc:147] Difference at 1: 0.154053, expected 0
# E0000 00:00:1760108223.773235   95470 buffer_comparator.cc:147] Difference at 2: 0.17395, expected -nan
# E0000 00:00:1760108223.773238   95470 buffer_comparator.cc:147] Difference at 3: 0.17981, expected 0
# E0000 00:00:1760108223.773240   95470 buffer_comparator.cc:147] Difference at 4: 0.137207, expected -nan
# E0000 00:00:1760108223.773243   95470 buffer_comparator.cc:147] Difference at 5: 0.244873, expected 0
# E0000 00:00:1760108223.773245   95470 buffer_comparator.cc:147] Difference at 6: 0.15625, expected -nan
# E0000 00:00:1760108223.773247   95470 buffer_comparator.cc:147] Difference at 7: 0.185425, expected 0
# E0000 00:00:1760108223.773249   95470 buffer_comparator.cc:147] Difference at 8: 0.218628, expected -nan
# E0000 00:00:1760108223.773252   95470 buffer_comparator.cc:147] Difference at 9: 0.172974, expected 0
# 2025-10-10 20:57:03.773265: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,128,128,3]{3,2,1,0}, f16[64,3,3,3]{3,2,1,0}, f16[64]{0}, f16[2,126,126,64]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:03.773273: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:03.773276: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:03.773279: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:03.773281: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:03.773286: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108223.838451   95470 buffer_comparator.cc:147] Difference at 0: 0.169067, expected -nan
# E0000 00:00:1760108223.838505   95470 buffer_comparator.cc:147] Difference at 1: 0.154053, expected 0
# E0000 00:00:1760108223.838513   95470 buffer_comparator.cc:147] Difference at 2: 0.17395, expected -nan
# E0000 00:00:1760108223.838515   95470 buffer_comparator.cc:147] Difference at 3: 0.17981, expected 0
# E0000 00:00:1760108223.838518   95470 buffer_comparator.cc:147] Difference at 4: 0.137207, expected -nan
# E0000 00:00:1760108223.838520   95470 buffer_comparator.cc:147] Difference at 5: 0.244873, expected 0
# E0000 00:00:1760108223.838523   95470 buffer_comparator.cc:147] Difference at 6: 0.15625, expected -nan
# E0000 00:00:1760108223.838525   95470 buffer_comparator.cc:147] Difference at 7: 0.185425, expected 0
# E0000 00:00:1760108223.838528   95470 buffer_comparator.cc:147] Difference at 8: 0.218628, expected -nan
# E0000 00:00:1760108223.838531   95470 buffer_comparator.cc:147] Difference at 9: 0.172974, expected 0
# 2025-10-10 20:57:03.838545: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,128,128,3]{3,2,1,0}, f16[64,3,3,3]{3,2,1,0}, f16[64]{0}, f16[2,126,126,64]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-10-10 20:57:03.838555: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:03.838558: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:03.838561: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:03.838563: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:03.838568: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108224.164380   95470 buffer_comparator.cc:147] Difference at 0: 5.23828, expected -nan
# E0000 00:00:1760108224.164433   95470 buffer_comparator.cc:147] Difference at 1: 5.12891, expected 0
# E0000 00:00:1760108224.164440   95470 buffer_comparator.cc:147] Difference at 2: 5.11719, expected -nan
# E0000 00:00:1760108224.164443   95470 buffer_comparator.cc:147] Difference at 3: 5.15625, expected 0
# E0000 00:00:1760108224.164445   95470 buffer_comparator.cc:147] Difference at 4: 5.16406, expected -nan
# E0000 00:00:1760108224.164448   95470 buffer_comparator.cc:147] Difference at 5: 5.21484, expected 0
# E0000 00:00:1760108224.164452   95470 buffer_comparator.cc:147] Difference at 6: 5.28516, expected -nan
# E0000 00:00:1760108224.164455   95470 buffer_comparator.cc:147] Difference at 7: 5.21094, expected 0
# E0000 00:00:1760108224.164457   95470 buffer_comparator.cc:147] Difference at 8: 5.09766, expected -nan
# E0000 00:00:1760108224.164459   95470 buffer_comparator.cc:147] Difference at 9: 5.26172, expected 0
# 2025-10-10 20:57:04.164476: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0}, f16[512,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng31{k2=8,k12=-1,k13=1,k14=0,k15=0,k17=128,k23=2} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-10-10 20:57:04.164486: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 20:57:04.164490: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 20:57:04.164493: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 20:57:04.164495: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 20:57:04.164501: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108224.254409   95470 buffer_comparator.cc:147] Difference at 0: 5.23828, expected -nan
# E0000 00:00:1760108224.254465   95470 buffer_comparator.cc:147] Difference at 1: 5.12891, expected 0
# E0000 00:00:1760108224.254472   95470 buffer_comparator.cc:147] Difference at 2: 5.11719, expected -nan
# E0000 00:00:1760108224.254475   95470 buffer_comparator.cc:147] Difference at 3: 5.15625, expected 0
# E0000 00:00:1760108224.254477   95470 buffer_comparator.cc:147] Difference at 4: 5.16406, expected -nan
# E0000 00:00:1760108224.254480   95470 buffer_comparator.cc:147] Difference at 5: 5.21484, expected 0
# E0000 00:00:1760108224.254483   95470 buffer_comparator.cc:147] Difference at 6: 5.28516, expected -nan
# E0000 00:00:1760108224.254485   95470 buffer_comparator.cc:147] Difference at 7: 5.21094, expected 0
# E0000 00:00:1760108224.254487   95470 buffer_comparator.cc:147] Difference at 8: 5.09766, expected -nan
# ...
# 2025-10-10 21:02:19.720356: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 21:02:19.720359: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 21:02:19.720362: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 21:02:19.720364: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 21:02:19.720369: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108539.769014   95475 buffer_comparator.cc:147] Difference at 0: 1.40137, expected -nan
# E0000 00:00:1760108539.769066   95475 buffer_comparator.cc:147] Difference at 1: 1.43359, expected 0
# E0000 00:00:1760108539.769073   95475 buffer_comparator.cc:147] Difference at 2: 1.3916, expected -nan
# E0000 00:00:1760108539.769075   95475 buffer_comparator.cc:147] Difference at 3: 1.37988, expected 0
# E0000 00:00:1760108539.769077   95475 buffer_comparator.cc:147] Difference at 4: 1.30859, expected -nan
# E0000 00:00:1760108539.769079   95475 buffer_comparator.cc:147] Difference at 5: 1.31641, expected 0
# E0000 00:00:1760108539.769082   95475 buffer_comparator.cc:147] Difference at 6: 1.47363, expected -nan
# E0000 00:00:1760108539.769084   95475 buffer_comparator.cc:147] Difference at 7: 1.33105, expected 0
# E0000 00:00:1760108539.769086   95475 buffer_comparator.cc:147] Difference at 8: 1.42773, expected -nan
# E0000 00:00:1760108539.769088   95475 buffer_comparator.cc:147] Difference at 9: 1.35156, expected 0
# 2025-10-10 21:02:19.769102: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[1,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,61,61,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng39{k2=0,k13=0,k14=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 21:02:19.769112: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 21:02:19.769115: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 21:02:19.769117: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 21:02:19.769119: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 21:02:19.769124: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 21:02:19.821481: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv (f16[1,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,61,61,128]{3,2,1,0}, f16[128,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108540.053457   95475 buffer_comparator.cc:147] Difference at 0: 0.366943, expected -nan
# E0000 00:00:1760108540.053509   95475 buffer_comparator.cc:147] Difference at 1: 0.345703, expected 0
# E0000 00:00:1760108540.053516   95475 buffer_comparator.cc:147] Difference at 2: 0.387939, expected -nan
# E0000 00:00:1760108540.053518   95475 buffer_comparator.cc:147] Difference at 3: 0.355713, expected 0
# E0000 00:00:1760108540.053521   95475 buffer_comparator.cc:147] Difference at 4: 0.355957, expected -nan
# E0000 00:00:1760108540.053523   95475 buffer_comparator.cc:147] Difference at 5: 0.321289, expected 0
# E0000 00:00:1760108540.053525   95475 buffer_comparator.cc:147] Difference at 6: 0.347656, expected -nan
# E0000 00:00:1760108540.053529   95475 buffer_comparator.cc:147] Difference at 7: 0.349609, expected 0
# E0000 00:00:1760108540.053532   95475 buffer_comparator.cc:147] Difference at 8: 0.343994, expected -nan
# E0000 00:00:1760108540.053534   95475 buffer_comparator.cc:147] Difference at 9: 0.334473, expected 0
# 2025-10-10 21:02:20.053547: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[1,63,63,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,61,61,128]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng30{k2=1,k13=0,k14=0,k23=0} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-10-10 21:02:20.053564: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 21:02:20.053569: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 21:02:20.053572: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 21:02:20.053574: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 21:02:20.053578: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108540.090917   95475 buffer_comparator.cc:147] Difference at 0: 0.366943, expected -nan
# E0000 00:00:1760108540.090965   95475 buffer_comparator.cc:147] Difference at 1: 0.345703, expected 0
# E0000 00:00:1760108540.090972   95475 buffer_comparator.cc:147] Difference at 2: 0.387939, expected -nan
# E0000 00:00:1760108540.090974   95475 buffer_comparator.cc:147] Difference at 3: 0.355713, expected 0
# E0000 00:00:1760108540.090977   95475 buffer_comparator.cc:147] Difference at 4: 0.355957, expected -nan
# E0000 00:00:1760108540.090979   95475 buffer_comparator.cc:147] Difference at 5: 0.321289, expected 0
# E0000 00:00:1760108540.090981   95475 buffer_comparator.cc:147] Difference at 6: 0.347656, expected -nan
# E0000 00:00:1760108540.090985   95475 buffer_comparator.cc:147] Difference at 7: 0.349609, expected 0
# E0000 00:00:1760108540.090987   95475 buffer_comparator.cc:147] Difference at 8: 0.343994, expected -nan
# E0000 00:00:1760108540.090990   95475 buffer_comparator.cc:147] Difference at 9: 0.334473, expected 0
# 2025-10-10 21:02:20.091002: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[1,63,63,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,61,61,128]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng30{k2=1,k13=0,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 21:02:20.091012: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 21:02:20.091015: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 21:02:20.091018: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 21:02:20.091020: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 21:02:20.091024: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 21:02:20.132203: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv (f16[1,63,63,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,61,61,128]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# E0000 00:00:1760108542.224548   95475 buffer_comparator.cc:147] Difference at 0: 0.714355, expected -nan
# E0000 00:00:1760108542.224600   95475 buffer_comparator.cc:147] Difference at 1: 0.641113, expected 0
# E0000 00:00:1760108542.224607   95475 buffer_comparator.cc:147] Difference at 2: 0.683105, expected -nan
# E0000 00:00:1760108542.224610   95475 buffer_comparator.cc:147] Difference at 3: 0.717285, expected 0
# E0000 00:00:1760108542.224612   95475 buffer_comparator.cc:147] Difference at 4: 0.687012, expected -nan
# E0000 00:00:1760108542.224615   95475 buffer_comparator.cc:147] Difference at 5: 0.733887, expected 0
# E0000 00:00:1760108542.224617   95475 buffer_comparator.cc:147] Difference at 6: 0.67627, expected -nan
# E0000 00:00:1760108542.224619   95475 buffer_comparator.cc:147] Difference at 7: 0.684082, expected 0
# E0000 00:00:1760108542.224622   95475 buffer_comparator.cc:147] Difference at 8: 0.663086, expected -nan
# E0000 00:00:1760108542.224624   95475 buffer_comparator.cc:147] Difference at 9: 0.681152, expected 0
# 2025-10-10 21:02:22.224637: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng30{k2=4,k13=0,k14=0,k23=0} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-10-10 21:02:22.224647: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 21:02:22.224650: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 21:02:22.224653: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 21:02:22.224655: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 21:02:22.224660: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# E0000 00:00:1760108542.303963   95475 buffer_comparator.cc:147] Difference at 0: 0.714355, expected -nan
# E0000 00:00:1760108542.304016   95475 buffer_comparator.cc:147] Difference at 1: 0.641113, expected 0
# E0000 00:00:1760108542.304023   95475 buffer_comparator.cc:147] Difference at 2: 0.683105, expected -nan
# E0000 00:00:1760108542.304026   95475 buffer_comparator.cc:147] Difference at 3: 0.717285, expected 0
# E0000 00:00:1760108542.304028   95475 buffer_comparator.cc:147] Difference at 4: 0.687012, expected -nan
# E0000 00:00:1760108542.304031   95475 buffer_comparator.cc:147] Difference at 5: 0.733887, expected 0
# E0000 00:00:1760108542.304034   95475 buffer_comparator.cc:147] Difference at 6: 0.67627, expected -nan
# E0000 00:00:1760108542.304036   95475 buffer_comparator.cc:147] Difference at 7: 0.684082, expected 0
# E0000 00:00:1760108542.304039   95475 buffer_comparator.cc:147] Difference at 8: 0.663086, expected -nan
# E0000 00:00:1760108542.304041   95475 buffer_comparator.cc:147] Difference at 9: 0.681152, expected 0
# 2025-10-10 21:02:22.304056: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:753] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} for eng30{k2=4,k13=0,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-10-10 21:02:22.304067: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:314] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-10-10 21:02:22.304069: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:315] Platform: Compute Capability 7.5
# 2025-10-10 21:02:22.304073: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:316] Driver: 12.6.0
# 2025-10-10 21:02:22.304075: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:317] Runtime: 12.8.0
# 2025-10-10 21:02:22.304080: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:322] cudnn version: 9.10.2
# 2025-10-10 21:02:22.464504: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 380s 741ms/step - accuracy: 0.7446 - loss: 4.0862 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 2/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 284s 648ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 3/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 4/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 5/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 6/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 7/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 8/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 9/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 285s 650ms/step - accuracy: 0.7469 - loss: 4.0801 - val_accuracy: 0.7653 - val_loss: 3.7828
# Epoch 10/50
# 121/439 ━━━━━━━━━━━━━━━━━━━━ 3:18 623ms/step - accuracy: 0.8014 - loss: 3.2015

# %% [markdown]
# # **Evaluate the Trained Model**
# After training, we will evaluate the model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)
# Out:
# 2025-04-14 20:38:45.933200: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,126,126,64]{3,2,1,0} %bitcast.2851, f16[64,3,3,64]{3,2,1,0} %bitcast.2752), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:48.187332: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,126,126,64]{3,2,1,0} %bitcast.2851, f16[64,3,3,64]{3,2,1,0} %bitcast.2752), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:48.422910: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,126,126,64]{3,2,1,0} %bitcast.2851, f16[64,3,3,64]{3,2,1,0} %bitcast.2752), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744641532.697877    5804 buffer_comparator.cc:156] Difference at 0: 0.245972, expected -nan
# E0000 00:00:1744641532.698029    5804 buffer_comparator.cc:156] Difference at 1: 0.166504, expected 0
# E0000 00:00:1744641532.698036    5804 buffer_comparator.cc:156] Difference at 2: 0.182251, expected -nan
# E0000 00:00:1744641532.698039    5804 buffer_comparator.cc:156] Difference at 3: 0.162231, expected 0
# E0000 00:00:1744641532.698041    5804 buffer_comparator.cc:156] Difference at 4: 0.175049, expected -nan
# E0000 00:00:1744641532.698042    5804 buffer_comparator.cc:156] Difference at 5: 0.190796, expected 0
# E0000 00:00:1744641532.698044    5804 buffer_comparator.cc:156] Difference at 6: 0.174438, expected -nan
# E0000 00:00:1744641532.698046    5804 buffer_comparator.cc:156] Difference at 7: 0.192993, expected 0
# E0000 00:00:1744641532.698048    5804 buffer_comparator.cc:156] Difference at 8: 0.219604, expected -nan
# E0000 00:00:1744641532.698050    5804 buffer_comparator.cc:156] Difference at 9: 0.207153, expected 0
# 2025-04-14 20:38:52.698510: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.100 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,128,128,3]{3,2,1,0} %bitcast.2734, f16[64,3,3,3]{3,2,1,0} %bitcast.2740, f16[64]{0} %bitcast.2744, f16[32,126,126,64]{3,2,1,0} %bitcast.2756), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 20:38:52.698530: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:52.698533: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:52.698537: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:52.698538: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:52.698552: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641532.871359    5804 buffer_comparator.cc:156] Difference at 0: 0.245972, expected -nan
# E0000 00:00:1744641532.871424    5804 buffer_comparator.cc:156] Difference at 1: 0.166504, expected 0
# E0000 00:00:1744641532.871429    5804 buffer_comparator.cc:156] Difference at 2: 0.182251, expected -nan
# E0000 00:00:1744641532.871431    5804 buffer_comparator.cc:156] Difference at 3: 0.162231, expected 0
# E0000 00:00:1744641532.871433    5804 buffer_comparator.cc:156] Difference at 4: 0.175049, expected -nan
# E0000 00:00:1744641532.871435    5804 buffer_comparator.cc:156] Difference at 5: 0.190796, expected 0
# E0000 00:00:1744641532.871438    5804 buffer_comparator.cc:156] Difference at 6: 0.174438, expected -nan
# E0000 00:00:1744641532.871439    5804 buffer_comparator.cc:156] Difference at 7: 0.192993, expected 0
# E0000 00:00:1744641532.871441    5804 buffer_comparator.cc:156] Difference at 8: 0.219604, expected -nan
# E0000 00:00:1744641532.871443    5804 buffer_comparator.cc:156] Difference at 9: 0.207153, expected 0
# 2025-04-14 20:38:52.871960: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.100 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,128,128,3]{3,2,1,0} %bitcast.2734, f16[64,3,3,3]{3,2,1,0} %bitcast.2740, f16[64]{0} %bitcast.2744, f16[32,126,126,64]{3,2,1,0} %bitcast.2756), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 20:38:52.871994: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:52.871999: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:52.872003: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:52.872005: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:52.872018: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641533.467726    5804 buffer_comparator.cc:156] Difference at 0: 0.245972, expected -nan
# E0000 00:00:1744641533.467788    5804 buffer_comparator.cc:156] Difference at 1: 0.166504, expected 0
# E0000 00:00:1744641533.467793    5804 buffer_comparator.cc:156] Difference at 2: 0.182251, expected -nan
# E0000 00:00:1744641533.467795    5804 buffer_comparator.cc:156] Difference at 3: 0.162231, expected 0
# E0000 00:00:1744641533.467797    5804 buffer_comparator.cc:156] Difference at 4: 0.175049, expected -nan
# E0000 00:00:1744641533.467799    5804 buffer_comparator.cc:156] Difference at 5: 0.190796, expected 0
# E0000 00:00:1744641533.467801    5804 buffer_comparator.cc:156] Difference at 6: 0.174438, expected -nan
# E0000 00:00:1744641533.467803    5804 buffer_comparator.cc:156] Difference at 7: 0.192993, expected 0
# E0000 00:00:1744641533.467805    5804 buffer_comparator.cc:156] Difference at 8: 0.219604, expected -nan
# E0000 00:00:1744641533.467807    5804 buffer_comparator.cc:156] Difference at 9: 0.207153, expected 0
# 2025-04-14 20:38:53.468183: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.100 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,128,128,3]{3,2,1,0} %bitcast.2734, f16[64,3,3,3]{3,2,1,0} %bitcast.2740, f16[64]{0} %bitcast.2744, f16[32,126,126,64]{3,2,1,0} %bitcast.2756), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 20:38:53.468211: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:53.468215: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:53.468219: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:53.468220: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:53.468232: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 20:38:54.157635: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.64 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,61,61,128]{3,2,1,0} %bitcast.3026, f16[128,3,3,128]{3,2,1,0} %bitcast.2927), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:54.272301: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.64 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,61,61,128]{3,2,1,0} %bitcast.3026, f16[128,3,3,128]{3,2,1,0} %bitcast.2927), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:54.386692: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.64 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,61,61,128]{3,2,1,0} %bitcast.3026, f16[128,3,3,128]{3,2,1,0} %bitcast.2927), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744641538.188327    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.188389    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.188394    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.188396    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.188398    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.188400    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.188402    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.188403    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.188406    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.188408    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.188773: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=0,k13=1,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:58.188801: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.188804: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.188807: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.188808: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.188821: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.269831    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.269893    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.269898    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.269900    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.269902    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.269904    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.269905    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.269908    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.269910    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.269912    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.270189: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=3,k13=0,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:58.270216: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.270219: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.270222: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.270223: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.270233: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.347484    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.347545    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.347549    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.347551    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.347553    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.347555    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.347557    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.347558    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.347560    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.347562    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.347869: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=0,k13=0,k14=0,k18=0,k23=0}
# 2025-04-14 20:38:58.347896: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.347899: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.347902: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.347903: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.347914: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.487011    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.487079    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.487084    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.487085    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.487087    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.487089    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.487091    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.487093    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.487095    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.487097    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.487405: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=0,k13=0,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:58.487450: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.487455: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.487459: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.487461: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.487473: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.624913    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.624980    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.624984    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.624986    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.624988    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.624990    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.624991    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.624993    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.624996    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.624998    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.625320: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=4,k13=0,k14=0,k18=0,k23=0}
# 2025-04-14 20:38:58.625349: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.625352: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.625355: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.625357: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.625369: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.724158    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.724206    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.724210    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.724212    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.724214    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.724216    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.724218    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.724219    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.724221    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.724223    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.724460: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=4,k13=0,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:58.724474: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.724476: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.724480: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.724482: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.724493: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.825327    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.825391    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.825396    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.825399    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.825401    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.825402    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.825404    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.825406    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.825408    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.825409    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.825643: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=1,k13=0,k14=0,k18=0,k23=0}
# 2025-04-14 20:38:58.825674: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.825677: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.825680: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.825682: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.825694: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.945722    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.945777    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.945781    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.945783    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.945785    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.945787    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.945789    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.945791    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.945793    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.945795    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.946060: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng8{k2=0,k13=0,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:58.946083: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.946086: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.946090: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.946093: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.946107: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.045995    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.046060    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.046064    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.046066    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.046068    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.046070    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.046072    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.046074    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.046076    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.046079    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.046305: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=5,k13=1,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:59.046333: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.046336: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.046339: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.046340: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.046350: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.124558    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.124620    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.124625    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.124627    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.124628    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.124632    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.124634    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.124635    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.124637    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.124639    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.124852: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=5,k13=1,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:59.124879: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.124882: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.124885: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.124887: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.124897: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.244279    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.244346    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.244350    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.244352    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.244354    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.244356    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.244358    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.244359    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.244362    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.244364    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.244596: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng8{k2=4,k13=0,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:59.244613: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.244615: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.244618: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.244621: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.244632: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.333010    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.333089    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.333094    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.333096    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.333099    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.333100    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.333102    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.333106    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.333108    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.333110    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.333438: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng31{k2=2,k6=3,k13=1,k14=0,k22=2}
# 2025-04-14 20:38:59.333491: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.333496: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.333501: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.333503: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.333517: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.422644    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.422766    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.422786    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.422789    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.422791    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.422793    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.422795    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.422797    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# ...
# E0000 00:00:1744641567.485964    5803 buffer_comparator.cc:156] Difference at 7: 3.18359, expected 0
# E0000 00:00:1744641567.485967    5803 buffer_comparator.cc:156] Difference at 8: 3.06055, expected -nan
# E0000 00:00:1744641567.485969    5803 buffer_comparator.cc:156] Difference at 9: 3.04297, expected 0
# 2025-04-14 20:39:27.485989: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.112 = (f16[16,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,15,15,128]{3,2,1,0} %bitcast.3259, f16[256,3,3,128]{3,2,1,0} %bitcast.3265, f16[256]{0} %bitcast.3269, f16[16,13,13,256]{3,2,1,0} %bitcast.3281), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng9{k2=0,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 20:39:27.486002: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:27.486005: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:27.486007: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:27.486009: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:27.486015: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641567.508763    5803 buffer_comparator.cc:156] Difference at 0: 3.11523, expected -nan
# E0000 00:00:1744641567.508828    5803 buffer_comparator.cc:156] Difference at 1: 3.11719, expected 0
# E0000 00:00:1744641567.508832    5803 buffer_comparator.cc:156] Difference at 2: 3.08203, expected -nan
# E0000 00:00:1744641567.508835    5803 buffer_comparator.cc:156] Difference at 3: 2.97852, expected 0
# E0000 00:00:1744641567.508836    5803 buffer_comparator.cc:156] Difference at 4: 3.10938, expected -nan
# E0000 00:00:1744641567.508838    5803 buffer_comparator.cc:156] Difference at 5: 3.20117, expected 0
# E0000 00:00:1744641567.508840    5803 buffer_comparator.cc:156] Difference at 6: 3.05859, expected -nan
# E0000 00:00:1744641567.508842    5803 buffer_comparator.cc:156] Difference at 7: 3.18359, expected 0
# E0000 00:00:1744641567.508846    5803 buffer_comparator.cc:156] Difference at 8: 3.06055, expected -nan
# E0000 00:00:1744641567.508848    5803 buffer_comparator.cc:156] Difference at 9: 3.04297, expected 0
# 2025-04-14 20:39:27.508870: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.112 = (f16[16,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,15,15,128]{3,2,1,0} %bitcast.3259, f16[256,3,3,128]{3,2,1,0} %bitcast.3265, f16[256]{0} %bitcast.3269, f16[16,13,13,256]{3,2,1,0} %bitcast.3281), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng9{k2=0,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 20:39:27.508884: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:27.508886: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:27.508888: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:27.508890: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:27.508898: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 20:39:27.871976: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,5,5,512]{3,2,1,0} %bitcast.3551, f16[512,3,3,512]{3,2,1,0} %bitcast.3452), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:39:28.078621: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,5,5,512]{3,2,1,0} %bitcast.3551, f16[512,3,3,512]{3,2,1,0} %bitcast.3452), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:39:28.179015: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,5,5,512]{3,2,1,0} %bitcast.3551, f16[512,3,3,512]{3,2,1,0} %bitcast.3452), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744641568.594377    5803 buffer_comparator.cc:156] Difference at 0: 5.97656, expected -nan
# E0000 00:00:1744641568.594430    5803 buffer_comparator.cc:156] Difference at 1: 6.03516, expected 0
# E0000 00:00:1744641568.594435    5803 buffer_comparator.cc:156] Difference at 2: 6.10938, expected -nan
# E0000 00:00:1744641568.594437    5803 buffer_comparator.cc:156] Difference at 3: 5.94531, expected 0
# E0000 00:00:1744641568.594439    5803 buffer_comparator.cc:156] Difference at 4: 5.87891, expected -nan
# E0000 00:00:1744641568.594442    5803 buffer_comparator.cc:156] Difference at 5: 5.99609, expected 0
# E0000 00:00:1744641568.594443    5803 buffer_comparator.cc:156] Difference at 6: 5.99609, expected -nan
# E0000 00:00:1744641568.594445    5803 buffer_comparator.cc:156] Difference at 7: 5.96484, expected 0
# E0000 00:00:1744641568.594447    5803 buffer_comparator.cc:156] Difference at 8: 5.76562, expected -nan
# E0000 00:00:1744641568.594449    5803 buffer_comparator.cc:156] Difference at 9: 5.99609, expected 0
# 2025-04-14 20:39:28.594466: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,7,7,256]{3,2,1,0} %bitcast.3434, f16[512,3,3,256]{3,2,1,0} %bitcast.3440, f16[512]{0} %bitcast.3444, f16[16,5,5,512]{3,2,1,0} %bitcast.3456), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng22{k2=5,k12=5,k13=1,k14=0,k15=0,k17=43,k18=1,k23=0} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 20:39:28.594478: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:28.594481: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:28.594483: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:28.594485: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:28.594490: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641568.635014    5803 buffer_comparator.cc:156] Difference at 0: 5.97656, expected -nan
# E0000 00:00:1744641568.635067    5803 buffer_comparator.cc:156] Difference at 1: 6.03516, expected 0
# E0000 00:00:1744641568.635072    5803 buffer_comparator.cc:156] Difference at 2: 6.10938, expected -nan
# E0000 00:00:1744641568.635074    5803 buffer_comparator.cc:156] Difference at 3: 5.94531, expected 0
# E0000 00:00:1744641568.635076    5803 buffer_comparator.cc:156] Difference at 4: 5.87891, expected -nan
# E0000 00:00:1744641568.635078    5803 buffer_comparator.cc:156] Difference at 5: 5.99609, expected 0
# E0000 00:00:1744641568.635081    5803 buffer_comparator.cc:156] Difference at 6: 5.99609, expected -nan
# E0000 00:00:1744641568.635083    5803 buffer_comparator.cc:156] Difference at 7: 5.96484, expected 0
# E0000 00:00:1744641568.635084    5803 buffer_comparator.cc:156] Difference at 8: 5.76562, expected -nan
# E0000 00:00:1744641568.635086    5803 buffer_comparator.cc:156] Difference at 9: 5.99609, expected 0
# 2025-04-14 20:39:28.635104: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,7,7,256]{3,2,1,0} %bitcast.3434, f16[512,3,3,256]{3,2,1,0} %bitcast.3440, f16[512]{0} %bitcast.3444, f16[16,5,5,512]{3,2,1,0} %bitcast.3456), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng22{k2=5,k12=5,k13=1,k14=0,k15=0,k17=43,k18=1,k23=0} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 20:39:28.635118: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:28.635121: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:28.635124: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:28.635125: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:28.635130: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641568.772768    5803 buffer_comparator.cc:156] Difference at 0: 5.97656, expected -nan
# E0000 00:00:1744641568.772823    5803 buffer_comparator.cc:156] Difference at 1: 6.03516, expected 0
# E0000 00:00:1744641568.772828    5803 buffer_comparator.cc:156] Difference at 2: 6.10938, expected -nan
# E0000 00:00:1744641568.772830    5803 buffer_comparator.cc:156] Difference at 3: 5.94531, expected 0
# E0000 00:00:1744641568.772832    5803 buffer_comparator.cc:156] Difference at 4: 5.87891, expected -nan
# E0000 00:00:1744641568.772833    5803 buffer_comparator.cc:156] Difference at 5: 5.99609, expected 0
# E0000 00:00:1744641568.772836    5803 buffer_comparator.cc:156] Difference at 6: 5.99609, expected -nan
# E0000 00:00:1744641568.772837    5803 buffer_comparator.cc:156] Difference at 7: 5.96484, expected 0
# E0000 00:00:1744641568.772839    5803 buffer_comparator.cc:156] Difference at 8: 5.76562, expected -nan
# E0000 00:00:1744641568.772841    5803 buffer_comparator.cc:156] Difference at 9: 5.99609, expected 0
# 2025-04-14 20:39:28.772860: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,7,7,256]{3,2,1,0} %bitcast.3434, f16[512,3,3,256]{3,2,1,0} %bitcast.3440, f16[512]{0} %bitcast.3444, f16[16,5,5,512]{3,2,1,0} %bitcast.3456), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng22{k2=5,k12=5,k13=1,k14=0,k15=0,k17=43,k18=1,k23=0} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 20:39:28.772874: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:28.772877: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:28.772880: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:28.772881: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:28.772887: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 17s/step - accuracy: 0.2257 - loss: 12.4803

# %% [markdown]
# # **Save the Model**
# Now, we will save the model to avoid training it from scratch every time we need the model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.keras'

# Save the Model.
convlstm_model.save(model_file_name)

# %% [markdown]
# ### Load the saved Model

# %%
convlstm_model = tf.keras.models.load_model('convlstm_model___Date_Time_2025_03_25__23_43_26___Loss_0.5146016478538513___Accuracy_0.8333333134651184.keras')

# %% [markdown]
# # **Step 4.3: Plot Model's Loss & Accuracy Curves**
# Now, we will create a function `plot_metric()` to visualize the training and validation metrics. We already have separate metrics from our training and validation steps so now we just have to visualize them.

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):

  '''
  This function will plot the metrics passed to it in a graph.

  Args:

    model_training_history: A history object containing a record of training and validation loss values and metrics values at successive epochs.
    metric_name_1:          The name of the first metric that needs to be plotted in the graph.
    metric_name_2:          The name of the second metric that needs to be plotted in the graph.
    plot_name:              The title of the graph.

  '''

  # Get metric values using metric names as identifiers.
  metric_value_1 = model_training_history.history[metric_name_1]
  metric_value_2 = model_training_history.history[metric_name_2]

  # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
  epochs = range(len(metric_value_1))

  # Plot the graph
  plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
  plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

  # Add title to the plot
  plt.title(str(plot_name))

  # Add legend to the plot.
  plt.legend()

# %% [markdown]
# Now we will utilize the function `plot_metric()` created above, to visualize and understand the metrics.

# %%
# Visualize the training and validation loss metrics.
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrics.
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# # **Step 5: Implement The LRCN Approach**
#
# In this step, we will implement the LRCN approach by combining Convolution and LSTM layers in a single model. Another similar approach can be to use a CNN model and LSTM model trained separately.
#
# The CNN model can be used to extract spatial features from the frames in the video, and for this purpose, a pre-trained model can be used, that can be fine-tuned for the problem. And the LSTM model can then use the features extracted by CNN, to predict the action being performed in the video.
#
# But here, we will implement another approach known as the `Long-term Recurrent Convolutional Network (LRCN)`, which combines CNN and LSTM layers in a single model. The Convolutional layers are used for spatial features extraction from the frames, and the extracted spatial features are fed to LSTM layes at each time-steps for temporal sequence modeling. This way the network learns spatiotemporal features directly in an end-to-end training, resulting in a robust model.

# %% [markdown]
# # **Step 5.1: Construct the Model**
#
# To implement our LRCN architecture, we will use time-distributed `Conv2D` layers which will be followed by `MaxPooling2D` and `Dropout` layers. The feature extracted from the `Conv2D` layers will be then flattened using the `Flatten` layer and will be fed to a `LSTM` layer. The `Dense` layer with `softmax` activation will then use the output from the `LSTM` layer to predict the action being performed.

# %%
def create_LRCN_model():
  '''
  This function will construct the required LRCN model.

  Returns:
    model: It is the required constructed LRCN model.

  '''

  # We will use a Sequencial model for model construction.
  model = Sequential()

  # Define the Model Architecture.

  model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'), input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

  model.add(TimeDistributed(MaxPooling2D((4, 4))))
  model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((4, 4))))
  model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((2, 2))))
  model.add(TimeDistributed(Dropout(0.25)))
  
  model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((2, 2))))
  model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((2, 2))))
  #model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Flatten()))

  model.add(LSTM(32))

  # Use Bidirectional LSTM here instead of normal LSTM
  #smodel.add(Bidirectional(LSTM(32)))

  model.add(Dense(len(CLASSES_LIST), activation = "softmax"))

  # Display the models summary.
  model.summary()

  # Return the constructed LRCN model.
  return model

# %% [markdown]
# Now we will utilize the function `create_LRCN_model()` created above to construct the required LRCN model.

# %%
# Construct the required LRCN model
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!!")
# Out:
# /mnt/f/Study/Academic/Part 4/Project/Sentinel/TestWithWebCam/.venv/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760682456.234154    6890 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:10:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 10, 128, 128,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 10, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 10, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 10, 32, 32, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 10, 8, 8, 32)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 10, 8, 8, 32)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ (None, 10, 8, 8, 64)   │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 10, 4, 4, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 10, 4, 4, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 10, 4, 4, 64)   │        36,928 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 10, 2, 2, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 10, 2, 2, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_12             │ (None, 10, 2, 2, 128)  │        73,856 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_13             │ (None, 10, 1, 1, 128)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_14             │ (None, 10, 128)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 155,108 (605.89 KB)
#  Trainable params: 155,108 (605.89 KB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!!

# %% [markdown]
# # **Check Model's Structure**
# Now we will use the `plot_model()` function to check the structure of the constructed `LRCN` model. As we had checked for the previous model.

# %%
# Plot the structure of the constructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # **Step 5.2: Compile & Train the Model**
#
# After checking the structure, we will compile and start training the model.

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4, shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - accuracy: 0.8201 - loss: 0.5534 - val_accuracy: 0.5000 - val_loss: 0.7158
# Epoch 2/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8380 - loss: 0.4730 - val_accuracy: 0.7500 - val_loss: 0.3860
# Epoch 3/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.8638 - loss: 0.4085 - val_accuracy: 0.7500 - val_loss: 0.6457
# Epoch 4/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8638 - loss: 0.3915 - val_accuracy: 0.7500 - val_loss: 0.3746
# Epoch 5/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.8869 - loss: 0.3546 - val_accuracy: 0.7500 - val_loss: 0.6173
# Epoch 6/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9075 - loss: 0.2902 - val_accuracy: 0.7500 - val_loss: 0.7302
# Epoch 7/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.8715 - loss: 0.3289 - val_accuracy: 0.7500 - val_loss: 0.6273
# Epoch 8/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.8689 - loss: 0.4134 - val_accuracy: 0.7500 - val_loss: 0.4084
# Epoch 9/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9023 - loss: 0.2772 - val_accuracy: 0.7500 - val_loss: 0.5064
# Epoch 10/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9100 - loss: 0.2413 - val_accuracy: 0.7500 - val_loss: 0.6175
# Epoch 11/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8997 - loss: 0.2711 - val_accuracy: 1.0000 - val_loss: 0.2659
# Epoch 12/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.8920 - loss: 0.2853 - val_accuracy: 0.5000 - val_loss: 0.6342
# Epoch 13/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9434 - loss: 0.1711 - val_accuracy: 0.7500 - val_loss: 0.5410
# Epoch 14/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.9152 - loss: 0.1934 - val_accuracy: 0.7500 - val_loss: 0.3697
# Epoch 15/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9409 - loss: 0.1814 - val_accuracy: 0.7500 - val_loss: 0.3696
# Epoch 16/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9460 - loss: 0.1675 - val_accuracy: 0.7500 - val_loss: 0.8303
# Epoch 17/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9537 - loss: 0.1442 - val_accuracy: 0.7500 - val_loss: 1.0201
# Epoch 18/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9692 - loss: 0.0966 - val_accuracy: 0.7500 - val_loss: 0.7153
# Epoch 19/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9512 - loss: 0.1541 - val_accuracy: 0.5000 - val_loss: 2.2665
# Epoch 20/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9075 - loss: 0.2459 - val_accuracy: 0.7500 - val_loss: 1.2513
# Epoch 21/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9589 - loss: 0.1264 - val_accuracy: 0.7500 - val_loss: 1.3615
# Epoch 22/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9769 - loss: 0.0798 - val_accuracy: 0.7500 - val_loss: 1.7134
# Epoch 23/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9692 - loss: 0.1102 - val_accuracy: 0.7500 - val_loss: 1.4775
# Epoch 24/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9871 - loss: 0.0496 - val_accuracy: 0.5000 - val_loss: 2.0825
# Epoch 25/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9434 - loss: 0.1744 - val_accuracy: 0.5000 - val_loss: 1.5510
# Epoch 26/70
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9512 - loss: 0.1393 - val_accuracy: 0.7500 - val_loss: 1.4089

# %%
"""
Simplified LRCN Model - Optimized for Small Datasets
This version is more likely to succeed with 297 videos
"""

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, TimeDistributed, Dropout, LSTM, Dense, 
    BatchNormalization, GlobalAveragePooling2D
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import numpy as np

# ============================================================
# Simpler Model Architecture
# ============================================================

def create_simplified_LRCN():
    """
    Simplified LRCN optimized for small datasets:
    - MobileNetV2 (lighter than EfficientNetB0)
    - Single LSTM layer
    - Less aggressive dropout
    - Fewer dense layers
    """
    print("   Creating simplified model...")
    
    video_input = Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # MobileNetV2 is more stable and requires less data
    base_model = MobileNetV2(
        include_top=False,
        weights='imagenet',
        input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3),
        alpha=1.0  # Full model size
    )
    
    # Freeze base model
    base_model.trainable = False
    
    # Feature extraction
    x = TimeDistributed(base_model)(video_input)
    x = TimeDistributed(GlobalAveragePooling2D())(x)
    x = TimeDistributed(Dropout(0.2))(x)  # Light dropout
    
    # Temporal modeling - Single LSTM is often enough
    x = LSTM(128, return_sequences=False, 
             dropout=0.3, recurrent_dropout=0.2)(x)
    
    # Classification head - Simpler
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    outputs = Dense(len(CLASSES_LIST), activation='softmax')(x)
    
    model = Model(inputs=video_input, outputs=outputs)
    
    return model, base_model

# Create model
LRCN_model, base_model = create_simplified_LRCN()
print(f"   ✅ Total parameters: {LRCN_model.count_params():,}")

# ============================================================
# Calculate Class Weights (Important for Imbalanced Data)
# ============================================================

from sklearn.utils.class_weight import compute_class_weight

# Get class indices from one-hot labels
train_class_indices = np.argmax(labels_train_aug, axis=1)

# Compute class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_class_indices),
    y=train_class_indices
)

class_weights = dict(enumerate(class_weights_array))
print(f"\n   Class weights: {class_weights}")

# ============================================================
# Training Configuration
# ============================================================

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=15,  # More patience for small datasets
    mode='max',
    restore_best_weights=True,
    verbose=1,
    min_delta=0.005
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    mode='min',
    verbose=1
)

checkpoint = ModelCheckpoint(
    filepath='best_simplified_LRCN.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

# Higher initial learning rate for frozen base
optimizer = Adam(learning_rate=0.001)

LRCN_model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
)

# ============================================================
# Training
# ============================================================

print("\n" + "="*60)
print("Training Simplified LRCN")
print("="*60)

history = LRCN_model.fit(
    x=features_train_aug,
    y=labels_train_aug,
    epochs=50,
    batch_size=8,  # Larger batch size for stability
    shuffle=True,
    validation_split=0.2,
    class_weight=class_weights,  # IMPORTANT: Handle imbalance
    callbacks=[early_stopping, reduce_lr, checkpoint],
    verbose=1
)

# ============================================================
# Evaluation
# ============================================================

print("\n" + "="*60)
print("Evaluation")
print("="*60)

# Load best model
LRCN_model = tf.keras.models.load_model('best_simplified_LRCN.keras')

# Evaluate
test_loss, test_accuracy = LRCN_model.evaluate(features_test, labels_test, verbose=1)

print(f"\n📊 RESULTS:")
print(f"   Test Accuracy: {test_accuracy*100:.2f}%")
print(f"   Test Loss: {test_loss:.4f}")
print(f"   Best Val Accuracy: {max(history.history['val_accuracy'])*100:.2f}%")

# ============================================================
# If still not good, try fine-tuning
# ============================================================

if test_accuracy < 0.70:
    print("\n" + "="*60)
    print("Performance Below 70% - Attempting Fine-Tuning")
    print("="*60)
    
    # Unfreeze last 20 layers
    base_model.trainable = True
    for layer in base_model.layers[:-20]:
        layer.trainable = False
    
    print(f"   Unfrozen {len([l for l in base_model.layers if l.trainable])} layers")
    
    # Recompile with lower learning rate
    optimizer_ft = Adam(learning_rate=0.00001)
    LRCN_model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer_ft,
        metrics=['accuracy']
    )
    
    # Fine-tune
    history_ft = LRCN_model.fit(
        x=features_train_aug,
        y=labels_train_aug,
        epochs=30,
        batch_size=8,
        shuffle=True,
        validation_split=0.2,
        class_weight=class_weights,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=1
    )
    
    # Re-evaluate
    test_loss, test_accuracy = LRCN_model.evaluate(features_test, labels_test, verbose=1)
    print(f"\n📊 AFTER FINE-TUNING:")
    print(f"   Test Accuracy: {test_accuracy*100:.2f}%")
    print(f"   Test Loss: {test_loss:.4f}")

# ============================================================
# Confusion Matrix and Per-Class Accuracy
# ============================================================

print("\n" + "="*60)
print("Detailed Performance Analysis")
print("="*60)

from sklearn.metrics import confusion_matrix, classification_report

# Get predictions
y_pred = LRCN_model.predict(features_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(labels_test, axis=1)

# Confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

print("\nConfusion Matrix:")
print(cm)

print("\nPer-Class Report:")
print(classification_report(
    y_true_classes, 
    y_pred_classes, 
    target_names=CLASSES_LIST,
    zero_division=0
))

# Visualize confusion matrix
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=CLASSES_LIST,
            yticklabels=CLASSES_LIST)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

print("\n✅ Confusion matrix saved as 'confusion_matrix.png'")
print("✅ Best model saved as 'best_simplified_LRCN.keras'")
# Out:
#    Creating simplified model...
#    ✅ Total parameters: 2,996,932
#
#    Class weights: {0: np.float64(1.076086956521739), 1: np.float64(2.3951612903225805), 2: np.float64(1.3026315789473684), 3: np.float64(0.5303571428571429)}
#
# ============================================================
# Training Simplified LRCN
# ============================================================
# 2025-10-17 19:16:37.575109: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 1119879168 exceeds 10% of free system memory.
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.3045 - loss: 2.0602
# Epoch 1: val_accuracy improved from None to 0.41341, saving model to best_simplified_LRCN.keras
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.2879 - loss: 1.9164 - val_accuracy: 0.4134 - val_loss: 1.3528 - learning_rate: 0.0010
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.2751 - loss: 1.6831
# Epoch 2: val_accuracy improved from 0.41341 to 0.48603, saving model to best_simplified_LRCN.keras
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.3034 - loss: 1.6458 - val_accuracy: 0.4860 - val_loss: 1.3543 - learning_rate: 0.0010
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.3220 - loss: 1.5538
# Epoch 3: val_accuracy did not improve from 0.48603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.3399 - loss: 1.5326 - val_accuracy: 0.2793 - val_loss: 1.5022 - learning_rate: 0.0010
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.3234 - loss: 1.4455
# Epoch 4: val_accuracy improved from 0.48603 to 0.49721, saving model to best_simplified_LRCN.keras
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 17s 196ms/step - accuracy: 0.3680 - loss: 1.4412 - val_accuracy: 0.4972 - val_loss: 1.3076 - learning_rate: 0.0010
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.3871 - loss: 1.3706
# Epoch 5: val_accuracy did not improve from 0.49721
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.4115 - loss: 1.3447 - val_accuracy: 0.4190 - val_loss: 1.3727 - learning_rate: 0.0010
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4270 - loss: 1.2954
# Epoch 6: val_accuracy did not improve from 0.49721
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 184ms/step - accuracy: 0.4537 - loss: 1.2707 - val_accuracy: 0.4469 - val_loss: 1.3055 - learning_rate: 0.0010
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4762 - loss: 1.2147
# Epoch 7: val_accuracy did not improve from 0.49721
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 172ms/step - accuracy: 0.4761 - loss: 1.2283 - val_accuracy: 0.4413 - val_loss: 1.2906 - learning_rate: 0.0010
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4964 - loss: 1.2319
# Epoch 8: val_accuracy did not improve from 0.49721
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 17s 194ms/step - accuracy: 0.5014 - loss: 1.2267 - val_accuracy: 0.4637 - val_loss: 1.4170 - learning_rate: 0.0010
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4665 - loss: 1.1772
# Epoch 9: val_accuracy did not improve from 0.49721
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.4831 - loss: 1.1544 - val_accuracy: 0.4302 - val_loss: 1.3699 - learning_rate: 0.0010
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.4968 - loss: 1.1364
# Epoch 10: val_accuracy improved from 0.49721 to 0.51397, saving model to best_simplified_LRCN.keras
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 18s 200ms/step - accuracy: 0.5169 - loss: 1.1219 - val_accuracy: 0.5140 - val_loss: 1.3543 - learning_rate: 0.0010
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5111 - loss: 1.1051
# Epoch 11: val_accuracy did not improve from 0.51397
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 17s 190ms/step - accuracy: 0.5421 - loss: 1.1056 - val_accuracy: 0.3352 - val_loss: 1.4514 - learning_rate: 0.0010
# Epoch 12/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5270 - loss: 1.0929
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_accuracy did not improve from 0.51397
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 171ms/step - accuracy: 0.5407 - loss: 1.0767 - val_accuracy: 0.5140 - val_loss: 1.3064 - learning_rate: 0.0010
# Epoch 13/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5420 - loss: 1.0388
# Epoch 13: val_accuracy did not improve from 0.51397
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 151ms/step - accuracy: 0.5758 - loss: 1.0123 - val_accuracy: 0.3464 - val_loss: 1.3331 - learning_rate: 5.0000e-04
# Epoch 14/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5701 - loss: 1.0052
# Epoch 14: val_accuracy improved from 0.51397 to 0.55307, saving model to best_simplified_LRCN.keras
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 165ms/step - accuracy: 0.5913 - loss: 0.9781 - val_accuracy: 0.5531 - val_loss: 1.3257 - learning_rate: 5.0000e-04
# Epoch 15/50
# 84/89 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5603 - loss: 0.9888
# Epoch 15: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 175ms/step - accuracy: 0.5955 - loss: 0.9641 - val_accuracy: 0.4693 - val_loss: 1.3111 - learning_rate: 5.0000e-04
# Epoch 16/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5726 - loss: 0.9891
# Epoch 16: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 18s 202ms/step - accuracy: 0.6124 - loss: 0.9580 - val_accuracy: 0.4525 - val_loss: 1.3608 - learning_rate: 5.0000e-04
# Epoch 17/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6264 - loss: 0.9425
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 17: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - accuracy: 0.6292 - loss: 0.9178 - val_accuracy: 0.2793 - val_loss: 1.6278 - learning_rate: 5.0000e-04
# Epoch 18/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6116 - loss: 0.9246
# Epoch 18: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 161ms/step - accuracy: 0.6390 - loss: 0.8995 - val_accuracy: 0.3408 - val_loss: 1.4093 - learning_rate: 2.5000e-04
# Epoch 19/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6392 - loss: 0.8636
# Epoch 19: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 167ms/step - accuracy: 0.6559 - loss: 0.8698 - val_accuracy: 0.3464 - val_loss: 1.3879 - learning_rate: 2.5000e-04
# Epoch 20/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6271 - loss: 0.8619
# Epoch 20: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.6320 - loss: 0.8578 - val_accuracy: 0.4637 - val_loss: 1.3415 - learning_rate: 2.5000e-04
# Epoch 21/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.6626 - loss: 0.8310
# Epoch 21: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - accuracy: 0.6826 - loss: 0.8193 - val_accuracy: 0.4358 - val_loss: 1.3643 - learning_rate: 2.5000e-04
# Epoch 22/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6516 - loss: 0.8441
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 22: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 169ms/step - accuracy: 0.6728 - loss: 0.8137 - val_accuracy: 0.4860 - val_loss: 1.3328 - learning_rate: 2.5000e-04
# Epoch 23/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6652 - loss: 0.8372
# Epoch 23: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.6699 - loss: 0.8114 - val_accuracy: 0.4469 - val_loss: 1.3783 - learning_rate: 1.2500e-04
# Epoch 24/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6536 - loss: 0.8632
# Epoch 24: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 172ms/step - accuracy: 0.6699 - loss: 0.8276 - val_accuracy: 0.5084 - val_loss: 1.3444 - learning_rate: 1.2500e-04
# Epoch 25/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6705 - loss: 0.7967
# Epoch 25: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 17s 193ms/step - accuracy: 0.6798 - loss: 0.7938 - val_accuracy: 0.5084 - val_loss: 1.3530 - learning_rate: 1.2500e-04
# Epoch 26/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6754 - loss: 0.8023
# Epoch 26: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 161ms/step - accuracy: 0.7065 - loss: 0.7680 - val_accuracy: 0.4693 - val_loss: 1.3453 - learning_rate: 1.2500e-04
# Epoch 27/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7024 - loss: 0.7632
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 27: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 168ms/step - accuracy: 0.7093 - loss: 0.7461 - val_accuracy: 0.4581 - val_loss: 1.3785 - learning_rate: 1.2500e-04
# Epoch 28/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.7022 - loss: 0.7685
# Epoch 28: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 160ms/step - accuracy: 0.7079 - loss: 0.7694 - val_accuracy: 0.4637 - val_loss: 1.3728 - learning_rate: 6.2500e-05
# Epoch 29/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6712 - loss: 0.7743
# Epoch 29: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 181ms/step - accuracy: 0.6980 - loss: 0.7537 - val_accuracy: 0.4581 - val_loss: 1.3906 - learning_rate: 6.2500e-05
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 14.
#
# ============================================================
# Evaluation
# ============================================================
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 293ms/step - accuracy: 0.6300 - loss: 1.3018
#
# 📊 RESULTS:
#    Test Accuracy: 63.00%
#    Test Loss: 1.3018
#    Best Val Accuracy: 55.31%
#
# ============================================================
# Performance Below 70% - Attempting Fine-Tuning
# ============================================================
#    Unfrozen 20 layers
# Epoch 1/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5743 - loss: 1.0144
# Epoch 1: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 54s 260ms/step - accuracy: 0.5801 - loss: 0.9871 - val_accuracy: 0.4860 - val_loss: 1.3411 - learning_rate: 1.0000e-05
# Epoch 2/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6079 - loss: 0.9454
# Epoch 2: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 172ms/step - accuracy: 0.6376 - loss: 0.9107 - val_accuracy: 0.4749 - val_loss: 1.3467 - learning_rate: 1.0000e-05
# Epoch 3/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5594 - loss: 0.9948
# Epoch 3: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - accuracy: 0.5801 - loss: 0.9650 - val_accuracy: 0.4749 - val_loss: 1.3484 - learning_rate: 1.0000e-05
# Epoch 4/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6083 - loss: 0.9469
# Epoch 4: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.6138 - loss: 0.9237 - val_accuracy: 0.4804 - val_loss: 1.3477 - learning_rate: 1.0000e-05
# Epoch 5/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5934 - loss: 0.9431
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 5: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 166ms/step - accuracy: 0.5997 - loss: 0.9304 - val_accuracy: 0.4860 - val_loss: 1.3382 - learning_rate: 1.0000e-05
# Epoch 6/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5980 - loss: 0.9418
# Epoch 6: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 169ms/step - accuracy: 0.6138 - loss: 0.9210 - val_accuracy: 0.4860 - val_loss: 1.3394 - learning_rate: 5.0000e-06
# Epoch 7/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5905 - loss: 0.9555
# Epoch 7: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - accuracy: 0.6067 - loss: 0.9404 - val_accuracy: 0.4860 - val_loss: 1.3342 - learning_rate: 5.0000e-06
# Epoch 8/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6169 - loss: 0.9344
# Epoch 8: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 177ms/step - accuracy: 0.6208 - loss: 0.9217 - val_accuracy: 0.4860 - val_loss: 1.3322 - learning_rate: 5.0000e-06
# Epoch 9/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5932 - loss: 0.9626
# Epoch 9: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 166ms/step - accuracy: 0.5997 - loss: 0.9397 - val_accuracy: 0.4860 - val_loss: 1.3235 - learning_rate: 5.0000e-06
# Epoch 10/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5773 - loss: 0.9786
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 10: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - accuracy: 0.5843 - loss: 0.9519 - val_accuracy: 0.4860 - val_loss: 1.3186 - learning_rate: 5.0000e-06
# Epoch 11/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5999 - loss: 0.9370
# Epoch 11: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - accuracy: 0.6110 - loss: 0.9243 - val_accuracy: 0.4860 - val_loss: 1.3228 - learning_rate: 2.5000e-06
# Epoch 12/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5934 - loss: 0.9541
# Epoch 12: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 171ms/step - accuracy: 0.6208 - loss: 0.9075 - val_accuracy: 0.4860 - val_loss: 1.3254 - learning_rate: 2.5000e-06
# Epoch 13/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6136 - loss: 0.9384
# Epoch 13: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.6067 - loss: 0.9393 - val_accuracy: 0.4860 - val_loss: 1.3262 - learning_rate: 2.5000e-06
# Epoch 14/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6188 - loss: 0.9511
# Epoch 14: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 176ms/step - accuracy: 0.6039 - loss: 0.9346 - val_accuracy: 0.4860 - val_loss: 1.3289 - learning_rate: 2.5000e-06
# Epoch 15/30
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6204 - loss: 0.9411
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 15: val_accuracy did not improve from 0.55307
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 168ms/step - accuracy: 0.6334 - loss: 0.9284 - val_accuracy: 0.4860 - val_loss: 1.3260 - learning_rate: 2.5000e-06
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.6000 - loss: 1.3527
#
# 📊 AFTER FINE-TUNING:
#    Test Accuracy: 60.00%
#    Test Loss: 1.3527
#
# ============================================================
# Detailed Performance Analysis
# ============================================================
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
#
# Confusion Matrix:
# [[16  4  4  5]
#  [ 2  3  0  2]
#  [ 0  0 14  0]
#  [10  7  6 27]]
#
# Per-Class Report:
#                 precision    recall  f1-score   support
#
#       accident       0.57      0.55      0.56        29
#       fighting       0.21      0.43      0.29         7
#           fire       0.58      1.00      0.74        14
# normal_resized       0.79      0.54      0.64        50
#
#       accuracy                           0.60       100
#      macro avg       0.54      0.63      0.56       100
#   weighted avg       0.66      0.60      0.61       100
# ✅ Confusion matrix saved as 'confusion_matrix.png'
# ✅ Best model saved as 'best_simplified_LRCN.keras'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # **Evaluating the Trained Model**
#
# As done for previous one, we will evaluate the `LRCN` model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 252ms/step - accuracy: 0.6600 - loss: 1.6876 - top_k_accuracy_float32: 0.9000

# %% [markdown]
# # **Save the Model**
# After that, we will save the model for future uses using the same technique we had used for previous model.

# %%
# Get the loss and accuracy from mode_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'multiclass_LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.keras'

# Save the Model.
LRCN_model.save(model_file_name)

# %% [markdown]
# ### Load the saved model

# %%
LRCN_model = tf.keras.models.load_model('LRCN_model___Date_Time_2025_03_27__02_14_17___Loss_0.44080331921577454___Accuracy_0.7708333134651184.keras')
# Out:
# I0000 00:00:1743022550.473532     739 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:10:00.0, compute capability: 7.5

# %% [markdown]
# # **Step 5.3: Plot Model's Loss & Accuracy Curves**
#
# Now we will utilize the function `plot_metric()` we had created above to visualize the training and validation metrics of this model.

# %%
# Visualize the training and validation loss matrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Visualize the training and validation loss matrices.
# ----> 2 plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')
#
# NameError: name 'plot_metric' is not defined

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Visualize the training and validation accuracy metrices.
# ----> 2 plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
#
# NameError: name 'plot_metric' is not defined

# %% [markdown]
# # **Step 6: Test the Best Performing Model on YouTube videos**

# %% [markdown]
# # **Create a Function to Download YouTube Videos**
#
# We will create a function `download_youtube_videos()` to download the YouTube videos first using `pafy` library. The library only requires a URL to a video to download it along with its associated metadata like the title of the video.

# %%
pafy.set_backend("yt_dlp")
def download_youtube_videos(youtube_video_url, output_directory):
    """
    This function downloads the YouTube video whose URL is passed to it as an argument.

    Args:
        youtube_video_url: URL of the video that is required to be downloaded.
        output_directory: The directory path to which the video needs to be stored after downloading.

    Returns:
        title: The title of the downloaded YouTube video.
    """

    # Create a video object which contains useful information about the video.
    video = pafy.new(youtube_video_url)

    # Retrieve the title of the video.
    title = video.title

    # Get the best available quality object for the video.
    video_best = video.getbest()

    # Construct the output file path.
    output_file_path = f'{output_directory}/{title}.mp4'

    # Download the YouTube video at the best available quality and store it to the constructed path.
    video_best.download(filepath=output_file_path, quiet=True)

    # Return the video title.
    return title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-107331fd889a> in <cell line: 0>()
# ----> 1 pafy.set_backend("yt_dlp")
#       2 def download_youtube_videos(youtube_video_url, output_directory):
#       3     """
#       4     This function downloads the YouTube video whose URL is passed to it as an argument.
#       5
#
# AttributeError: module 'pafy' has no attribute 'set_backend'

# %% [markdown]
# # **Download a Test Video**
#
# Now we will utilize the function `download_youtube_videos()` created above to download a youtube video on which the LRCN model will be tested.

# %%
# Make the Output directory if it does not exist
test_videos_directory = 'test_videos'
os.makedirs(test_videos_directory, exist_ok = True)

# Download a YouTube Video.
#video_title = download_youtube_videos('https://www.youtube.com/watch?v=mzelalrFNRk', test_videos_directory)
video_title = "test_video_1"

# Get the YouTube Video's path we just downloaded.
input_video_file_path = f'{test_videos_directory}/{video_title}.mp4'

# %% [markdown]
# # **Download The Model**

# %%
from google.colab import files

# Download the file
#files.download("convlstm_model___Date_Time_2025_01_18__17_14_01___Loss_0.2780801057815552___Accuracy_0.9027777910232544.keras")
files.download("LRCN_model___Date_Time_2025_01_18__18_17_00___Loss_0.28902676701545715___Accuracy_0.8819444179534912.keras")

# %% [markdown]
# # **Create a Function to perform Action Recognition on Videos**
#
# Next, we will create a function `predict_on_video()` that will simply read a video frame by frame from the path passed in as an argument and will perform action recognition on video and save the results.

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH, Loaded_Model):
    """
    This function will perform action recognition on a video using the LRCN model.
    Args:
        video_file_path: The path of the video file in the disk which action recognition is to be performed.
        output_file_path: The file where the corresponding prediction for the actions performed on each frame will be stored.
        SEQUENCE_LENGTH: Fixed number of frames in a video that can be fed to the model as one sequence.
    """

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_width = int(video_reader.get(cv.CAP_PROP_FRAME_WIDTH))
    original_height = int(video_reader.get(cv.CAP_PROP_FRAME_HEIGHT))

    # Initialize the VideoWriter object to store the output video in the disk.
    video_writer = cv.VideoWriter(output_file_path, cv.VideoWriter_fourcc('M', 'P', '4', 'V'), video_reader.get(cv.CAP_PROP_FPS), (original_width, original_height))

    # Declare a queue to store video frames.
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)

    # Define a queue to store video frames
    frames_queue = deque(maxlen=SEQUENCE_LENGTH)

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    while video_reader.isOpened():

      # Read the frame.
      ok, frame = video_reader.read()

      # Check if frame is not read properly then break the loop
      if not ok:
        break

      # Resize the Frame to fixed Dimensions.
      resized_frame = cv.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

      # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
      normalized_frame = resized_frame / 255

      # Appending the pre-processed frame into the frames list.
      frames_queue.append(normalized_frame)

      # Check if the number of frame in the queue are equal to the fixed sequence length.
      if len(frames_queue) == SEQUENCE_LENGTH:

        # Pass the normalized frames to the model and get the predicted probabilities.
        predicted_label_probabilities = Loaded_Model.predict(np.expand_dims(frames_queue, axis = 0))[0]

        # Get the index of class with highest probability.
        predicted_label = np.argmax(predicted_label_probabilities)

        # Get the class name using the retrieved index.
        predicted_class_name = CLASSES_LIST[predicted_label]
        
        if predicted_class_name == "accident":
          cv.putText(frame, "Abnormal Activity [ Accident ]", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
        
        elif predicted_class_name == "fighting":
          cv.putText(frame, "Abnormal Activity [ Fighting ]", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)

        elif predicted_class_name == "fire":
          cv.putText(frame, "Abnormal Activity [ Fire ]", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
        
        else:
          cv.putText(frame, "Normal Activity", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)

      # Write predicted class name on top of the Frame.
      #cv.putText(frame, predicted_class_name, (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

      # Write The frame into the disk using the VideoWriter Object.
      video_writer.write(frame)

    # Release the VideoCapture and VideoWriter objects.
    video_reader.release()
    video_writer.release()

# %% [markdown]
# # **Perform Action Recognition on the Test Video**
#
# Now we will utilize the function `predict_on_video()` created above to perform action recognition on the test video we had downloaded using the function `download_youtube_videos()` and display the ouput video with the predicted action overlayed on it.

# %%
test_videos_directory = 'test/outputs--multiclass_LRCN_model___Date_Time_2025_03_27__17_30_45___Loss_0.6180427074432373___Accuracy_0.8125'
input_videos_directory = 'test/inputs'

Loaded_Model = tf.keras.models.load_model('models/multiclass_LRCN_model___Date_Time_2025_03_27__17_30_45___Loss_0.6180427074432373___Accuracy_0.8125.keras')

#Loaded_Model = LRCN_model
#Loaded_Model = convlstm_model

# Fetch all .mp4 videos in input folder
video_files = [f for f in os.listdir(input_videos_directory) if f.endswith('.mp4')]
video_files.sort()  # optional: to keep order consistent

for i, video_file in enumerate(video_files, start=1):
    video_title = os.path.splitext(video_file)[0]  # e.g., "test_1"
    print(f'Performing Prediction On Video {i}: {video_file}')

    input_video_file_path = os.path.join(input_videos_directory, video_file)
    output_video_path = os.path.join(
        test_videos_directory,
        f'{video_title}-Output-SeqLen{SEQUENCE_LENGTH}.mp4'
    )

    # Perform Action Recognition on the Test Video.
    predict_on_video(input_video_file_path, output_video_path, SEQUENCE_LENGTH, Loaded_Model)

    # Optionally display the output
    # VideoFileClip(output_video_path, audio=False, target_resolution=(300,None)).ipython_display()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760987046.478886 2518025 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:10:00.0, compute capability: 7.5
# Performing Prediction On Video 1: test_4.mp4
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 2025-10-21 01:04:08.676991: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ -1s -850387us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ -1s -775937us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %% [markdown]
# # **Create a Function To Perform a Single Prediction on Videos**
#
# Now let's create a function that will perform a single prediction for the complete videos. We will extract evenly distributed `N (SEQUENCE_LENGTH)` frames from the entire video and pass them to the LRCN model. This approach is really usefull when we are working with videos containing only one activity as it saves unnecessary computations and time in that scenario.

# %%
def predict_single_action(video_file_path, SEQUENCE_LENGTH):
    """
    This function will perform single action recognition prediction on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    """

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv.CAP_PROP_FRAME_HEIGHT))

    # Declare a list to store video frames we will extract.
    frames_list = []

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after whice frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):

      # Set the current frame position of the video.
      video_reader.set(cv.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

      # Read a frame.
      success, frame = video_reader.read()

      # Check if frame is not read properly then break the loop
      if not success:
        break

      # Resize the Frame to fixed Dimensions.
      resized_frame = cv.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

      # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
      nomalized_frame = resized_frame / 255

      # Appending the pre-processed frame into the frame list
      frames_list.append(nomalized_frame)

    # Passing the pre-processed frames to the model and get the predicted probabilities.
    predicted_label_probabilities = LRCN_model.predict(np.expand_dims(frames_list, axis = 0))[0]

    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_label_probabilities)

    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]

    # Display the predicted action along with the prediction confidence.
    print(f'Action Required: {predicted_class_name}\nConfidence: {predicted_label_probabilities[predicted_label]}')

    # Release the VideoCapture object.
    video_reader.release()

# %% [markdown]
# # **Perform Single Prediction on a Test Video**
#
# Now we will utilize the function `predict_single_action()` created above to perform a single prediction on a complete youtube test video that we will download using the function `download_youtube_videos()` we had created above.

# %%
# Video file name
video_title = 'test_video_3'

# Construct the input youtube video path
input_video_file_path = f'{test_videos_directory}/{video_title}.avi'

# Perform Single Prediction on the Test Video.
predict_single_action(input_video_file_path, SEQUENCE_LENGTH)

# Display the input video.
#VideoFileClip(input_video_file_path, audio=False, target_resolution=(300,None)).ipython_display()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Action Required: RopeClimbing
# Confidence: 0.7695754766464233
