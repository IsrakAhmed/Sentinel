# %% [markdown]
# ### Import Libraries

# %%
import os
import cv2 as cv
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

#from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')
# Out:
# 2025-04-14 18:38:48.445851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744634329.954128    2370 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744634330.362916    2370 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744634334.319123    2370 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744634334.319156    2370 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744634334.319158    2370 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744634334.319160    2370 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-14 18:38:54.685932: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Reduce GPU Memory Usage
# ✅ Enable Memory Growth for TensorFlow

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
print("Available GPUs:", gpu_devices)

# Enable memory growth before TensorFlow initializes the GPU
if gpu_devices:
    try:
        for device in gpu_devices:
            tf.config.experimental.set_memory_growth(device, True)
        print("Memory growth enabled for GPUs.")
    except RuntimeError as e:
        print("Failed to set memory growth:", e)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Memory growth enabled for GPUs.

# %% [markdown]
# ### Set Numpy, Python and Tensorflow seeds to get consistent results on every execution.

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# For visualization, we will pick 20 random categories from the dataset and a random video from each selected category and will visualize the first frame of the selected videos with their associated labels written. This way we'll be able to visualize a subset of the datset.

# %%
ds_name = 'multi_class__short_ds_resized_128'

# Get the names of all classes/categories in the dataset
all_classes_names = os.listdir(ds_name)
num_classes = len(all_classes_names)
    
# Determine the number of rows and columns for the subplot
cols = min(num_classes, 5)  # Limit columns to 5 for better visualization
rows = (num_classes // cols) + (num_classes % cols > 0)
    
# Create a Matplotlib figure with an appropriate size
plt.figure(figsize=(cols * 4, rows * 4))
    
# Iterate through all classes
for counter, selected_class_name in enumerate(all_classes_names, 1):
    # Retrieve the list of all video files in the selected class directory
    video_files_names_list = os.listdir(f'{ds_name}/{selected_class_name}')
        
    if not video_files_names_list:
        continue  # Skip if the class folder is empty
        
    # Randomly select a video file from the list
    selected_video_file_name = random.choice(video_files_names_list)
        
    # Initialize a VideoCapture object to read from the video file
    video_reader = cv.VideoCapture(f'{ds_name}/{selected_class_name}/{selected_video_file_name}')
        
    # Read the first frame of the video file
    success, bgr_frame = video_reader.read()
        
    # Release the VideoCapture object
    video_reader.release()
        
    if not success:
        continue  # Skip if the frame could not be read
            
    # Convert the frame from BGR to RGB format
    rgb_frame = cv.cvtColor(bgr_frame, cv.COLOR_BGR2RGB)
            
    # Write the class name on the video frame
    cv.putText(rgb_frame, selected_class_name, (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
            
    # Display the frame
    plt.subplot(rows, cols, counter)
    plt.imshow(rgb_frame)
    plt.axis('off')
    plt.title(selected_class_name)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 2: Preprocess the Dataset
#
# Next, we will perform some preprocessing on the dataset. First, we will read the video files from the dataset and resize the frames of the videos to a fixed width and height, to reduce the computations and normalized the data to range [0 - 1] by dividing the pixel values with 255, which makes convergence faster while training the network.
#
# But first, Initializing some constants.

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 128, 128

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 8

# Specify the directory containing the UCF50 Dataset.
DATASET_DIR = "multi_class__short_ds_resized_128"

# Specify the list containing the names of the classes used for training.
CLASSES_LIST = ["accident", "fighting", "fire", "normal_resized"]

# %% [markdown]
# **Note:** *The IMAGE_HEIGHT, IMAGE_WIDTH and SQUENCE_LENGTH constants can be increased for better results, although increasing the sequence.*

# %% [markdown]
# ### Create a Function to Extract, Resize & Normalize Frames
#
# We will create a function **`frames_extraction()`** that will create a list containing the resized and normalized frames of a video whose path is passed to it as an argument. The function will read the video file frame by frame, although not all frames are added to the list as we will only need an evenly distributed sequence length of frames.

# %%
def frames_extraction(video_path):
  '''
  This function will extract the required frames from a video after resizing and normalizing them.
  Args:
    video_path: The path of the video in the disk, whose frames are to be extracted.
  Returns:
    frames_list: A list containing the resized and normalized frames of the video.
  '''

  # Declare a list to store video frames.
  frames_list = []

  # Read the video File using the VideoCapture object.
  video_reader = cv.VideoCapture(video_path)

  # Get The total number of frames in the video
  video_frames_count = int(video_reader.get(cv.CAP_PROP_FRAME_COUNT))

  # Calculate the interval after which frames will be added to the list.
  skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

  # Iterate through the Video Frames.
  for frame_counter in range(SEQUENCE_LENGTH):

    # Set the current frame position of the video.
    video_reader.set(cv.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

    # Reading the frame from the video.
    success, frame = video_reader.read()

    # Check if video frame is not successfully read then break the loop
    if not success:
      break

    # Resize the frame to fixed height and width.
    resized_frame = cv.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

    # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
    normalized_frame = resized_frame / 255

    # Append the normalized frame into the frames list
    frames_list.append(normalized_frame)

  # Release the VideoCapture object.
  video_reader.release()

  # Return the frames list.
  return frames_list

# %% [markdown]
# ### Create a Function for Dataset Creation
#
# Now we will create a function **`create_dataset()`** that will iterate through all classes specified in the **`CLASSES_LIST`** constant and will call the function **`frame_extraction()`** on every video file of the selected classes and return the frames (**`features`**), class index(**`labels`**), and video file path (**`video_files_paths`**).

# %%
def create_dataset():
  '''
  This function will extract the data of the selected classes and create the required dataset.

  Returns:

    features:             A List containing the extracted frames of the videos.
    labels:               A list containing the indexes of the classes associated with the videos.
    video_files_paths:    A list containing the paths of the videos in the disk.

  '''


  # Declare Empty Lists to store the features, labels and video file path values.
  features = []
  labels = []
  video_files_paths = []

  # Iterating through all the classes mentioned in the classes list
  for class_index, class_name in enumerate(CLASSES_LIST):

    # Display the name of the class whoose data is being extracted.
    print(f'Extracting Data of Class: {class_name}')

    # Get the list of video files present in the specific class name directory.
    files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

    # Iterate through all the files present in the files list.
    for file_name in files_list:

      # Get the complete video path.
      video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

      # Extract the frames of the video file.
      frames = frames_extraction(video_file_path)

      # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
      # So ignore the videos having frames less than the SEQUENCE_LENGTH.
      if len(frames) == SEQUENCE_LENGTH:

        # Append the data to their respective lists.
        features.append(frames)
        labels.append(class_index)
        video_files_paths.append(video_file_path)

  # Converting the features and labels lists to numpy arrays.
  features = np.asarray(features)
  labels = np.array(labels)

  # Return the frames, class index and video file path.
  return features, labels, video_files_paths

# %% [markdown]
# Now we will utilize the function **`create_dataset()`** created above to extract the data of the selected classes and create the required dataset.

# %%
# Create the dataset
features, labels, video_files_paths = create_dataset()

# Print the counts of features, labels, and video file paths
print(f"Number of features: {len(features)}")
print(f"Number of labels: {len(labels)}")
print(f"Number of video file paths: {len(video_files_paths)}")
# Out:
# Extracting Data of Class: accident
# Extracting Data of Class: fighting
# Extracting Data of Class: fire
# Extracting Data of Class: normal_resized
# Number of features: 190
# Number of labels: 190
# Number of video file paths: 190

# %% [markdown]
# Now we will convert **`labels`** (class indexes) into one-hot encoded vectors.

# %%
# Using Keras's to_categorical method to convert labels into one-hot encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %% [markdown]
# ### Step 3: Split the Data into Train and Test Set
#
# As of now, we have the required **`features`** (a Numpy array containing all the extracted frames of the videos) and **`one_hot_encoded_labels`** (also a Numpy array containing all class labels in one hot encoded format). So now, we will split our data to create training and testing sets. We will also shuffle the dataset before the split to avoid any bias and get splits representing the overall distribution of the data.

# %%
# Split the Data into Train (75%) and Test Set (25%).
#features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)


# Check for NaN or infinite values
if np.any(np.isnan(features)) or np.any(np.isinf(features)):
    print("Features contain NaN or infinite values.")
if np.any(np.isnan(one_hot_encoded_labels)) or np.any(np.isinf(one_hot_encoded_labels)):
    print("Labels contain NaN or infinite values.")

# Reduce the dataset size for troubleshooting (optional)
# features = features[:1000]
# one_hot_encoded_labels = one_hot_encoded_labels[:1000]

# Perform the train-test split
try:
    features_train, features_test, labels_train, labels_test = train_test_split(
        features, one_hot_encoded_labels, test_size=0.25, shuffle=True, random_state=seed_constant
    )
    print("Train-test split successful.")
except Exception as e:
    print(f"Error during train-test split: {e}")
# Out:
# Train-test split successful.

# %% [markdown]
# ### Step 4: Implement the ConvLSTM Approach
#
# In this step, we will implement the first approach by using a combination of ConvLSTM cells. A ConvLSTM cell is a variant of an LSTM network that contains convolutions operations in the network. It is an LSTM with convolution embedded in the architecture, which makes it capable of identifying spatial features of the data while keeping into account the temporal relation.
#
#
# For video classification, this approach effectively captures the spatial relation in the individual frames and the temporal relation across the different frames. As a result of this convolution structure, the ConvLSTM is capable of taking in 3-dimensional input (**`width, height, num_of_channels`**) whereas a simple LSTM only takes in 1-dimensional input hence an LSTM is incompatible for modeling Spatio-temporal data on its own.

# %% [markdown]
# ### Step 4.1: Construct the Model
#
# To Construct the Model, we will use Keras **`ConvLSTM2D`** recurrent layers. The **`ConvLSTM2D`** layer also takes in the number of filters and kernel size required for applying the convolutional operations. The output of the layer is flattened in the end and is fed to the **`Dense`** layer with softmax activation which outputs the probability each action category.
#
# We will also use **`MaxPooling3D`** layers to reduce the dimensions of frames and avoid unnecessary computations and **`Dropout`** layers to prevent **`overfitting`** the model on the data. The architecture is a simple one and has a small number of trainable parameters. This is because we are only dealing with a small subset of the dataset which does not require a large-scale model.

# %%
def create_convlstm_model():
  '''
  This function will construct the required convlstm model.

  Returns:

    model:  It is the required constructed convlstm model.

  '''

  # We will use a Sequencial model for model construction.
  model = Sequential()

  # Define the Model Architecture

  model.add(ConvLSTM2D(filters = 64, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True, input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 128, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))
  
  model.add(ConvLSTM2D(filters = 128, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 256, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 512, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last", recurrent_dropout = 0.2, return_sequences = True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  #model.add(TimeDistributed(Dropout(0.2)))

  model.add(Flatten())

  model.add(Dense(len(CLASSES_LIST), activation = "softmax"))

  # Display the models summary
  model.summary()

  # Return the constructed convlstm model.
  return model

# %% [markdown]
# Now we will utilize the function **`create_convlstm_model()`** created above, to contruct the required convlstm model.

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message.
print("Model Created Successfully!!")
# Out:
# I0000 00:00:1744634555.522176    2370 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:10:00.0, compute capability: 7.5
# /mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 8, 126, 126,    │       154,624 │
# │                                 │ 64)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 8, 63, 63, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 8, 63, 63, 64)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 8, 61, 61, 128) │       885,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 8, 31, 31, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 8, 31, 31, 128) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_2 (ConvLSTM2D)      │ (None, 8, 29, 29, 128) │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 8, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 8, 15, 15, 128) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)      │ (None, 8, 13, 13, 256) │     3,539,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 8, 7, 7, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 8, 7, 7, 256)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_4 (ConvLSTM2D)      │ (None, 8, 5, 5, 512)   │    14,157,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_4 (MaxPooling3D)  │ (None, 8, 3, 3, 512)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │       147,460 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,065,284 (76.54 MB)
#  Trainable params: 20,065,284 (76.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!!

# %% [markdown]
# # **Check Model's Structure**
# Now we will use the **`plot_model()`** function, to check the structure of the constructed model, this is helpful while constructing a complex network and making that the network is created corectly.

# %%
# Plot the structure of the constructed model.
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # **Step 4.2: Compile & Train the Model**
#
# Next, we will add an early stopping callback to prevent `overfitting` and start the training after compiling the model.

# %%
# Create an Instance of Early Stopping Callback
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 2 , shuffle = True, validation_split = 0.1, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/50
# 2025-04-14 18:43:30.786754: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 199753728 exceeds 10% of free system memory.
# 2025-04-14 18:43:30.994443: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 199753728 exceeds 10% of free system memory.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744634618.895775    5807 service.cc:152] XLA service 0x563532c7cd60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744634618.895836    5807 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2025-04-14 18:43:40.379439: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1744634622.588598    5807 cuda_dnn.cc:529] Loaded cuDNN version 90800
# E0000 00:00:1744634629.327571    5807 buffer_comparator.cc:156] Difference at 0: 5.23828, expected -nan
# E0000 00:00:1744634629.327630    5807 buffer_comparator.cc:156] Difference at 1: 5.12891, expected 0
# E0000 00:00:1744634629.327636    5807 buffer_comparator.cc:156] Difference at 2: 5.11719, expected -nan
# E0000 00:00:1744634629.327638    5807 buffer_comparator.cc:156] Difference at 3: 5.15625, expected 0
# E0000 00:00:1744634629.327640    5807 buffer_comparator.cc:156] Difference at 4: 5.16406, expected -nan
# E0000 00:00:1744634629.327642    5807 buffer_comparator.cc:156] Difference at 5: 5.21484, expected 0
# E0000 00:00:1744634629.327644    5807 buffer_comparator.cc:156] Difference at 6: 5.28516, expected -nan
# E0000 00:00:1744634629.327646    5807 buffer_comparator.cc:156] Difference at 7: 5.21094, expected 0
# E0000 00:00:1744634629.327648    5807 buffer_comparator.cc:156] Difference at 8: 5.09766, expected -nan
# E0000 00:00:1744634629.327650    5807 buffer_comparator.cc:156] Difference at 9: 5.26172, expected 0
# 2025-04-14 18:43:49.327678: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.36 = (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0} %bitcast.104110, f16[512,3,3,512]{3,2,1,0} %bitcast.103776), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_4_1/while/gradients/sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=8,k12=-1,k13=1,k14=0,k15=0,k17=128,k23=2} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:49.327694: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:49.327697: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:49.327699: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:49.327701: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:49.327707: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634629.481116    5807 buffer_comparator.cc:156] Difference at 0: 5.23828, expected -nan
# E0000 00:00:1744634629.481174    5807 buffer_comparator.cc:156] Difference at 1: 5.12891, expected 0
# E0000 00:00:1744634629.481179    5807 buffer_comparator.cc:156] Difference at 2: 5.11719, expected -nan
# E0000 00:00:1744634629.481183    5807 buffer_comparator.cc:156] Difference at 3: 5.15625, expected 0
# E0000 00:00:1744634629.481185    5807 buffer_comparator.cc:156] Difference at 4: 5.16406, expected -nan
# E0000 00:00:1744634629.481187    5807 buffer_comparator.cc:156] Difference at 5: 5.21484, expected 0
# E0000 00:00:1744634629.481189    5807 buffer_comparator.cc:156] Difference at 6: 5.28516, expected -nan
# E0000 00:00:1744634629.481191    5807 buffer_comparator.cc:156] Difference at 7: 5.21094, expected 0
# E0000 00:00:1744634629.481192    5807 buffer_comparator.cc:156] Difference at 8: 5.09766, expected -nan
# E0000 00:00:1744634629.481194    5807 buffer_comparator.cc:156] Difference at 9: 5.26172, expected 0
# 2025-04-14 18:43:49.481219: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.36 = (f16[2,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0} %bitcast.104110, f16[512,3,3,512]{3,2,1,0} %bitcast.103776), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_4_1/while/gradients/sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=8,k12=-1,k13=1,k14=0,k15=0,k17=128,k23=2} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:49.481232: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:49.481234: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:49.481237: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:49.481239: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:49.481246: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634629.752200    5807 buffer_comparator.cc:156] Difference at 0: 1.30469, expected -nan
# E0000 00:00:1744634629.752258    5807 buffer_comparator.cc:156] Difference at 1: 1.27148, expected 0
# E0000 00:00:1744634629.752262    5807 buffer_comparator.cc:156] Difference at 2: 1.29297, expected -nan
# E0000 00:00:1744634629.752265    5807 buffer_comparator.cc:156] Difference at 3: 1.30371, expected 0
# E0000 00:00:1744634629.752267    5807 buffer_comparator.cc:156] Difference at 4: 1.31348, expected -nan
# E0000 00:00:1744634629.752269    5807 buffer_comparator.cc:156] Difference at 5: 1.31543, expected 0
# E0000 00:00:1744634629.752270    5807 buffer_comparator.cc:156] Difference at 6: 1.28027, expected -nan
# E0000 00:00:1744634629.752272    5807 buffer_comparator.cc:156] Difference at 7: 1.19141, expected 0
# E0000 00:00:1744634629.752274    5807 buffer_comparator.cc:156] Difference at 8: 1.30469, expected -nan
# E0000 00:00:1744634629.752276    5807 buffer_comparator.cc:156] Difference at 9: 1.35645, expected 0
# 2025-04-14 18:43:49.752293: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.40 = (f16[2,7,7,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,5,5,512]{3,2,1,0} %bitcast.104110, f16[512,3,3,256]{3,2,1,0} %bitcast.103938), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_4_1/while/gradients/sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng42{k2=8,k12=-1,k13=1,k14=0,k17=128} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:49.752307: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:49.752310: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:49.752313: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:49.752314: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:49.752319: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634630.337098    5807 buffer_comparator.cc:156] Difference at 0: 2.64258, expected -nan
# E0000 00:00:1744634630.337148    5807 buffer_comparator.cc:156] Difference at 1: 2.6543, expected 0
# E0000 00:00:1744634630.337153    5807 buffer_comparator.cc:156] Difference at 2: 2.60547, expected -nan
# E0000 00:00:1744634630.337155    5807 buffer_comparator.cc:156] Difference at 3: 2.54102, expected 0
# E0000 00:00:1744634630.337157    5807 buffer_comparator.cc:156] Difference at 4: 2.60352, expected -nan
# E0000 00:00:1744634630.337159    5807 buffer_comparator.cc:156] Difference at 5: 2.6582, expected 0
# E0000 00:00:1744634630.337161    5807 buffer_comparator.cc:156] Difference at 6: 2.59766, expected -nan
# E0000 00:00:1744634630.337163    5807 buffer_comparator.cc:156] Difference at 7: 2.58984, expected 0
# E0000 00:00:1744634630.337165    5807 buffer_comparator.cc:156] Difference at 8: 2.68164, expected -nan
# E0000 00:00:1744634630.337167    5807 buffer_comparator.cc:156] Difference at 9: 2.62109, expected 0
# 2025-04-14 18:43:50.337189: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.44 = (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0} %bitcast.104668, f16[256,3,3,256]{3,2,1,0} %bitcast.104334), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_3_1/while/gradients/sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng42{k2=7,k12=3,k13=0,k14=0,k17=64} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:50.337203: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:50.337205: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:50.337208: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:50.337210: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:50.337217: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634630.387836    5807 buffer_comparator.cc:156] Difference at 0: 2.64258, expected -nan
# E0000 00:00:1744634630.387885    5807 buffer_comparator.cc:156] Difference at 1: 2.6543, expected 0
# E0000 00:00:1744634630.387890    5807 buffer_comparator.cc:156] Difference at 2: 2.60547, expected -nan
# E0000 00:00:1744634630.387892    5807 buffer_comparator.cc:156] Difference at 3: 2.54102, expected 0
# E0000 00:00:1744634630.387894    5807 buffer_comparator.cc:156] Difference at 4: 2.60352, expected -nan
# E0000 00:00:1744634630.387895    5807 buffer_comparator.cc:156] Difference at 5: 2.6582, expected 0
# E0000 00:00:1744634630.387897    5807 buffer_comparator.cc:156] Difference at 6: 2.59766, expected -nan
# E0000 00:00:1744634630.387899    5807 buffer_comparator.cc:156] Difference at 7: 2.58984, expected 0
# E0000 00:00:1744634630.387901    5807 buffer_comparator.cc:156] Difference at 8: 2.68164, expected -nan
# E0000 00:00:1744634630.387905    5807 buffer_comparator.cc:156] Difference at 9: 2.62109, expected 0
# 2025-04-14 18:43:50.387924: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.44 = (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0} %bitcast.104668, f16[256,3,3,256]{3,2,1,0} %bitcast.104334), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_3_1/while/gradients/sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng42{k2=7,k12=3,k13=0,k14=0,k17=64} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:50.387937: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:50.387940: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:50.387942: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:50.387944: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:50.387949: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 18:43:50.388000: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.44 = (f16[2,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0} %bitcast.104668, f16[256,3,3,256]{3,2,1,0} %bitcast.104334), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_3_1/while/gradients/sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744634630.591826    5807 buffer_comparator.cc:156] Difference at 0: 0.675781, expected -nan
# E0000 00:00:1744634630.591876    5807 buffer_comparator.cc:156] Difference at 1: 0.742676, expected 0
# E0000 00:00:1744634630.591881    5807 buffer_comparator.cc:156] Difference at 2: 0.679199, expected -nan
# E0000 00:00:1744634630.591885    5807 buffer_comparator.cc:156] Difference at 3: 0.675781, expected 0
# E0000 00:00:1744634630.591887    5807 buffer_comparator.cc:156] Difference at 4: 0.67334, expected -nan
# E0000 00:00:1744634630.591889    5807 buffer_comparator.cc:156] Difference at 5: 0.697754, expected 0
# E0000 00:00:1744634630.591891    5807 buffer_comparator.cc:156] Difference at 6: 0.658203, expected -nan
# E0000 00:00:1744634630.591893    5807 buffer_comparator.cc:156] Difference at 7: 0.645508, expected 0
# E0000 00:00:1744634630.591895    5807 buffer_comparator.cc:156] Difference at 8: 0.6875, expected -nan
# E0000 00:00:1744634630.591896    5807 buffer_comparator.cc:156] Difference at 9: 0.657227, expected 0
# 2025-04-14 18:43:50.591913: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.48 = (f16[2,15,15,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,13,13,256]{3,2,1,0} %bitcast.104668, f16[256,3,3,128]{3,2,1,0} %bitcast.104496), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_3_1/while/gradients/sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng42{k2=8,k12=-1,k13=1,k14=0,k17=128} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:50.591925: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:50.591928: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:50.591931: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:50.591933: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:50.591936: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634631.167506    5807 buffer_comparator.cc:156] Difference at 0: 1.30469, expected -nan
# E0000 00:00:1744634631.167563    5807 buffer_comparator.cc:156] Difference at 1: 1.33105, expected 0
# E0000 00:00:1744634631.167568    5807 buffer_comparator.cc:156] Difference at 2: 1.34668, expected -nan
# E0000 00:00:1744634631.167570    5807 buffer_comparator.cc:156] Difference at 3: 1.35156, expected 0
# E0000 00:00:1744634631.167573    5807 buffer_comparator.cc:156] Difference at 4: 1.34863, expected -nan
# E0000 00:00:1744634631.167575    5807 buffer_comparator.cc:156] Difference at 5: 1.4043, expected 0
# E0000 00:00:1744634631.167577    5807 buffer_comparator.cc:156] Difference at 6: 1.35547, expected -nan
# E0000 00:00:1744634631.167579    5807 buffer_comparator.cc:156] Difference at 7: 1.34961, expected 0
# E0000 00:00:1744634631.167581    5807 buffer_comparator.cc:156] Difference at 8: 1.36328, expected -nan
# E0000 00:00:1744634631.167583    5807 buffer_comparator.cc:156] Difference at 9: 1.38965, expected 0
# 2025-04-14 18:43:51.167599: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.52 = (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0} %bitcast.105226, f16[128,3,3,128]{3,2,1,0} %bitcast.104892), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_2_1/while/gradients/sequential_1/conv_lstm2d_2_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=5,k13=1,k14=0,k23=0} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:51.167613: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:51.167616: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:51.167618: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:51.167620: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:51.167624: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634631.214268    5807 buffer_comparator.cc:156] Difference at 0: 1.30469, expected -nan
# E0000 00:00:1744634631.214315    5807 buffer_comparator.cc:156] Difference at 1: 1.33105, expected 0
# E0000 00:00:1744634631.214319    5807 buffer_comparator.cc:156] Difference at 2: 1.34668, expected -nan
# E0000 00:00:1744634631.214321    5807 buffer_comparator.cc:156] Difference at 3: 1.35156, expected 0
# E0000 00:00:1744634631.214323    5807 buffer_comparator.cc:156] Difference at 4: 1.34863, expected -nan
# E0000 00:00:1744634631.214325    5807 buffer_comparator.cc:156] Difference at 5: 1.4043, expected 0
# E0000 00:00:1744634631.214327    5807 buffer_comparator.cc:156] Difference at 6: 1.35547, expected -nan
# E0000 00:00:1744634631.214329    5807 buffer_comparator.cc:156] Difference at 7: 1.34961, expected 0
# E0000 00:00:1744634631.214331    5807 buffer_comparator.cc:156] Difference at 8: 1.36328, expected -nan
# E0000 00:00:1744634631.214333    5807 buffer_comparator.cc:156] Difference at 9: 1.38965, expected 0
# 2025-04-14 18:43:51.214352: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.52 = (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0} %bitcast.105226, f16[128,3,3,128]{3,2,1,0} %bitcast.104892), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_2_1/while/gradients/sequential_1/conv_lstm2d_2_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=5,k13=1,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:51.214365: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:51.214367: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:51.214369: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:51.214371: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:51.214377: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 18:43:51.214427: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.52 = (f16[2,29,29,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0} %bitcast.105226, f16[128,3,3,128]{3,2,1,0} %bitcast.104892), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_2_1/while/gradients/sequential_1/conv_lstm2d_2_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744634631.393317    5807 buffer_comparator.cc:156] Difference at 0: 0.348145, expected -nan
# E0000 00:00:1744634631.393381    5807 buffer_comparator.cc:156] Difference at 1: 0.340088, expected 0
# E0000 00:00:1744634631.393387    5807 buffer_comparator.cc:156] Difference at 2: 0.378174, expected -nan
# E0000 00:00:1744634631.393391    5807 buffer_comparator.cc:156] Difference at 3: 0.374023, expected 0
# E0000 00:00:1744634631.393395    5807 buffer_comparator.cc:156] Difference at 4: 0.38208, expected -nan
# E0000 00:00:1744634631.393398    5807 buffer_comparator.cc:156] Difference at 5: 0.351807, expected 0
# E0000 00:00:1744634631.393402    5807 buffer_comparator.cc:156] Difference at 6: 0.35498, expected -nan
# E0000 00:00:1744634631.393406    5807 buffer_comparator.cc:156] Difference at 7: 0.335449, expected 0
# E0000 00:00:1744634631.393409    5807 buffer_comparator.cc:156] Difference at 8: 0.322998, expected -nan
# E0000 00:00:1744634631.393412    5807 buffer_comparator.cc:156] Difference at 9: 0.345947, expected 0
# 2025-04-14 18:43:51.393438: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.56 = (f16[2,31,31,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0} %bitcast.105226, f16[128,3,3,128]{3,2,1,0} %bitcast.105054), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_2_1/while/gradients/sequential_1/conv_lstm2d_2_1/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=5,k13=1,k14=0,k23=0} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:51.393456: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:51.393459: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:51.393463: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:51.393465: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:51.393475: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634631.443585    5807 buffer_comparator.cc:156] Difference at 0: 0.348145, expected -nan
# E0000 00:00:1744634631.443636    5807 buffer_comparator.cc:156] Difference at 1: 0.340088, expected 0
# E0000 00:00:1744634631.443641    5807 buffer_comparator.cc:156] Difference at 2: 0.378174, expected -nan
# E0000 00:00:1744634631.443643    5807 buffer_comparator.cc:156] Difference at 3: 0.374023, expected 0
# E0000 00:00:1744634631.443645    5807 buffer_comparator.cc:156] Difference at 4: 0.38208, expected -nan
# E0000 00:00:1744634631.443647    5807 buffer_comparator.cc:156] Difference at 5: 0.351807, expected 0
# E0000 00:00:1744634631.443650    5807 buffer_comparator.cc:156] Difference at 6: 0.35498, expected -nan
# E0000 00:00:1744634631.443652    5807 buffer_comparator.cc:156] Difference at 7: 0.335449, expected 0
# E0000 00:00:1744634631.443654    5807 buffer_comparator.cc:156] Difference at 8: 0.322998, expected -nan
# E0000 00:00:1744634631.443656    5807 buffer_comparator.cc:156] Difference at 9: 0.345947, expected 0
# 2025-04-14 18:43:51.443674: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.56 = (f16[2,31,31,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0} %bitcast.105226, f16[128,3,3,128]{3,2,1,0} %bitcast.105054), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_2_1/while/gradients/sequential_1/conv_lstm2d_2_1/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=5,k13=1,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:51.443688: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:51.443691: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:51.443693: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:51.443695: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:51.443700: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 18:43:51.443750: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.56 = (f16[2,31,31,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,29,29,128]{3,2,1,0} %bitcast.105226, f16[128,3,3,128]{3,2,1,0} %bitcast.105054), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_2_1/while/gradients/sequential_1/conv_lstm2d_2_1/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744634632.027055    5807 buffer_comparator.cc:156] Difference at 0: 1.33008, expected -nan
# E0000 00:00:1744634632.027116    5807 buffer_comparator.cc:156] Difference at 1: 1.3418, expected 0
# E0000 00:00:1744634632.027122    5807 buffer_comparator.cc:156] Difference at 2: 1.32227, expected -nan
# E0000 00:00:1744634632.027126    5807 buffer_comparator.cc:156] Difference at 3: 1.38477, expected 0
# E0000 00:00:1744634632.027129    5807 buffer_comparator.cc:156] Difference at 4: 1.41113, expected -nan
# E0000 00:00:1744634632.027131    5807 buffer_comparator.cc:156] Difference at 5: 1.37793, expected 0
# E0000 00:00:1744634632.027133    5807 buffer_comparator.cc:156] Difference at 6: 1.40918, expected -nan
# E0000 00:00:1744634632.027135    5807 buffer_comparator.cc:156] Difference at 7: 1.35547, expected 0
# E0000 00:00:1744634632.027137    5807 buffer_comparator.cc:156] Difference at 8: 1.37109, expected -nan
# E0000 00:00:1744634632.027138    5807 buffer_comparator.cc:156] Difference at 9: 1.38574, expected 0
# 2025-04-14 18:43:52.027161: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.60 = (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.105796, f16[128,3,3,128]{3,2,1,0} %bitcast.105450), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1_2/while/gradients/sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k13=0,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:52.027175: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:52.027177: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:52.027180: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:52.027182: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:52.027189: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634632.101777    5807 buffer_comparator.cc:156] Difference at 0: 1.33008, expected -nan
# E0000 00:00:1744634632.101849    5807 buffer_comparator.cc:156] Difference at 1: 1.3418, expected 0
# E0000 00:00:1744634632.101854    5807 buffer_comparator.cc:156] Difference at 2: 1.32227, expected -nan
# E0000 00:00:1744634632.101856    5807 buffer_comparator.cc:156] Difference at 3: 1.38477, expected 0
# E0000 00:00:1744634632.101858    5807 buffer_comparator.cc:156] Difference at 4: 1.41113, expected -nan
# E0000 00:00:1744634632.101860    5807 buffer_comparator.cc:156] Difference at 5: 1.37793, expected 0
# E0000 00:00:1744634632.101863    5807 buffer_comparator.cc:156] Difference at 6: 1.40918, expected -nan
# E0000 00:00:1744634632.101868    5807 buffer_comparator.cc:156] Difference at 7: 1.35547, expected 0
# E0000 00:00:1744634632.101872    5807 buffer_comparator.cc:156] Difference at 8: 1.37109, expected -nan
# E0000 00:00:1744634632.101875    5807 buffer_comparator.cc:156] Difference at 9: 1.38574, expected 0
# 2025-04-14 18:43:52.101898: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.60 = (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.105796, f16[128,3,3,128]{3,2,1,0} %bitcast.105450), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1_2/while/gradients/sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k13=0,k14=0,k23=0} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:52.101912: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:52.101914: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:52.101917: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:52.101919: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:52.101926: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 18:43:52.220241: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.60 = (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.105796, f16[128,3,3,128]{3,2,1,0} %bitcast.105450), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1_2/while/gradients/sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744634632.545664    5807 buffer_comparator.cc:156] Difference at 0: 0.307373, expected -nan
# E0000 00:00:1744634632.545717    5807 buffer_comparator.cc:156] Difference at 1: 0.364258, expected 0
# E0000 00:00:1744634632.545723    5807 buffer_comparator.cc:156] Difference at 2: 0.301758, expected -nan
# E0000 00:00:1744634632.545725    5807 buffer_comparator.cc:156] Difference at 3: 0.358643, expected 0
# E0000 00:00:1744634632.545727    5807 buffer_comparator.cc:156] Difference at 4: 0.351318, expected -nan
# E0000 00:00:1744634632.545729    5807 buffer_comparator.cc:156] Difference at 5: 0.330078, expected 0
# E0000 00:00:1744634632.545732    5807 buffer_comparator.cc:156] Difference at 6: 0.350098, expected -nan
# E0000 00:00:1744634632.545734    5807 buffer_comparator.cc:156] Difference at 7: 0.362305, expected 0
# E0000 00:00:1744634632.545736    5807 buffer_comparator.cc:156] Difference at 8: 0.394287, expected -nan
# E0000 00:00:1744634632.545738    5807 buffer_comparator.cc:156] Difference at 9: 0.333984, expected 0
# 2025-04-14 18:43:52.545756: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.64 = (f16[2,63,63,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.105796, f16[128,3,3,64]{3,2,1,0} %bitcast.105612), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1_2/while/gradients/sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=1,k13=0,k14=0,k23=0} vs eng18{k2=4,k4=3,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:52.545769: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:52.545772: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:52.545774: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:52.545776: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:52.545781: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634632.687602    5807 buffer_comparator.cc:156] Difference at 0: 0.307373, expected -nan
# E0000 00:00:1744634632.687656    5807 buffer_comparator.cc:156] Difference at 1: 0.364258, expected 0
# E0000 00:00:1744634632.687661    5807 buffer_comparator.cc:156] Difference at 2: 0.301758, expected -nan
# E0000 00:00:1744634632.687663    5807 buffer_comparator.cc:156] Difference at 3: 0.358643, expected 0
# E0000 00:00:1744634632.687665    5807 buffer_comparator.cc:156] Difference at 4: 0.351318, expected -nan
# E0000 00:00:1744634632.687667    5807 buffer_comparator.cc:156] Difference at 5: 0.330078, expected 0
# E0000 00:00:1744634632.687669    5807 buffer_comparator.cc:156] Difference at 6: 0.350098, expected -nan
# E0000 00:00:1744634632.687671    5807 buffer_comparator.cc:156] Difference at 7: 0.362305, expected 0
# E0000 00:00:1744634632.687673    5807 buffer_comparator.cc:156] Difference at 8: 0.394287, expected -nan
# E0000 00:00:1744634632.687675    5807 buffer_comparator.cc:156] Difference at 9: 0.333984, expected 0
# 2025-04-14 18:43:52.687695: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.64 = (f16[2,63,63,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.105796, f16[128,3,3,64]{3,2,1,0} %bitcast.105612), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1_2/while/gradients/sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=1,k13=0,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:43:52.687709: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:43:52.687711: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:43:52.687714: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:43:52.687716: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:43:52.687722: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 18:43:52.741532: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.64 = (f16[2,63,63,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.105796, f16[128,3,3,64]{3,2,1,0} %bitcast.105612), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1_2/while/gradients/sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 18:43:54.046516: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.106058, f16[128,3,3,128]{3,2,1,0} %bitcast.106071), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 18:43:54.046568: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.106058, f16[128,3,3,128]{3,2,1,0} %bitcast.106071), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 18:43:54.046581: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[2,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[2,61,61,128]{3,2,1,0} %bitcast.106058, f16[128,3,3,128]{3,2,1,0} %bitcast.106071), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# ...
# 2025-04-14 18:45:33.935091: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-input.68 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0} %bitcast.108236, f16[64,3,3,64]{3,2,1,0} %bitcast.107923), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1/while/gradients/sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=4,k13=0,k14=0,k23=0} vs eng18{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:45:33.935106: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:45:33.935109: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:45:33.935111: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:45:33.935113: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:45:33.935119: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 18:45:34.125498: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.68 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0} %bitcast.108236, f16[64,3,3,64]{3,2,1,0} %bitcast.107923), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1/conv_lstm2d_1/while/gradients/sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7_grad/Conv2DBackpropInput" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 18:45:35.111592: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0} %bitcast.108490, f16[64,3,3,64]{3,2,1,0} %bitcast.108503), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 18:45:35.191468: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0} %bitcast.108490, f16[64,3,3,64]{3,2,1,0} %bitcast.108503), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 18:45:35.290389: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,126,126,64]{3,2,1,0} %bitcast.108490, f16[64,3,3,64]{3,2,1,0} %bitcast.108503), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744634735.446694    5807 buffer_comparator.cc:156] Difference at 0: 0.137329, expected -nan
# E0000 00:00:1744634735.446789    5807 buffer_comparator.cc:156] Difference at 2: 0.257812, expected -nan
# E0000 00:00:1744634735.446836    5807 buffer_comparator.cc:156] Difference at 3: 0.224365, expected 0
# E0000 00:00:1744634735.446840    5807 buffer_comparator.cc:156] Difference at 4: 0.168335, expected -nan
# E0000 00:00:1744634735.446843    5807 buffer_comparator.cc:156] Difference at 6: 0.2229, expected -nan
# E0000 00:00:1744634735.446846    5807 buffer_comparator.cc:156] Difference at 7: 0.138794, expected 0
# E0000 00:00:1744634735.446849    5807 buffer_comparator.cc:156] Difference at 8: 0.169556, expected -nan
# E0000 00:00:1744634735.446852    5807 buffer_comparator.cc:156] Difference at 9: 0.195923, expected 0
# E0000 00:00:1744634735.446855    5807 buffer_comparator.cc:156] Difference at 10: 0.144653, expected -nan
# E0000 00:00:1744634735.446858    5807 buffer_comparator.cc:156] Difference at 11: 0.169067, expected 0
# 2025-04-14 18:45:35.446884: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,128,128,3]{3,2,1,0} %bitcast.108301, f16[64,3,3,3]{3,2,1,0} %bitcast.108307, f16[64]{0} %bitcast.108311, f16[1,126,126,64]{3,2,1,0} %bitcast.108326), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 18:45:35.446897: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:45:35.446900: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:45:35.446902: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:45:35.446904: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:45:35.446909: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634735.456057    5807 buffer_comparator.cc:156] Difference at 0: 0.137329, expected -nan
# E0000 00:00:1744634735.456117    5807 buffer_comparator.cc:156] Difference at 2: 0.257812, expected -nan
# E0000 00:00:1744634735.456163    5807 buffer_comparator.cc:156] Difference at 3: 0.224365, expected 0
# E0000 00:00:1744634735.456167    5807 buffer_comparator.cc:156] Difference at 4: 0.168335, expected -nan
# E0000 00:00:1744634735.456170    5807 buffer_comparator.cc:156] Difference at 6: 0.2229, expected -nan
# E0000 00:00:1744634735.456173    5807 buffer_comparator.cc:156] Difference at 7: 0.138794, expected 0
# E0000 00:00:1744634735.456176    5807 buffer_comparator.cc:156] Difference at 8: 0.169556, expected -nan
# E0000 00:00:1744634735.456179    5807 buffer_comparator.cc:156] Difference at 9: 0.195923, expected 0
# E0000 00:00:1744634735.456182    5807 buffer_comparator.cc:156] Difference at 10: 0.144653, expected -nan
# E0000 00:00:1744634735.456185    5807 buffer_comparator.cc:156] Difference at 11: 0.169067, expected 0
# 2025-04-14 18:45:35.456201: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,128,128,3]{3,2,1,0} %bitcast.108301, f16[64,3,3,3]{3,2,1,0} %bitcast.108307, f16[64]{0} %bitcast.108311, f16[1,126,126,64]{3,2,1,0} %bitcast.108326), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 18:45:35.456220: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:45:35.456223: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:45:35.456225: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:45:35.456227: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:45:35.456231: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744634735.508835    5807 buffer_comparator.cc:156] Difference at 0: 0.137329, expected -nan
# E0000 00:00:1744634735.508930    5807 buffer_comparator.cc:156] Difference at 2: 0.257812, expected -nan
# E0000 00:00:1744634735.508976    5807 buffer_comparator.cc:156] Difference at 3: 0.224365, expected 0
# E0000 00:00:1744634735.508980    5807 buffer_comparator.cc:156] Difference at 4: 0.168335, expected -nan
# E0000 00:00:1744634735.508983    5807 buffer_comparator.cc:156] Difference at 6: 0.2229, expected -nan
# E0000 00:00:1744634735.508986    5807 buffer_comparator.cc:156] Difference at 7: 0.138794, expected 0
# E0000 00:00:1744634735.508989    5807 buffer_comparator.cc:156] Difference at 8: 0.169556, expected -nan
# E0000 00:00:1744634735.508991    5807 buffer_comparator.cc:156] Difference at 9: 0.195923, expected 0
# E0000 00:00:1744634735.508994    5807 buffer_comparator.cc:156] Difference at 10: 0.144653, expected -nan
# E0000 00:00:1744634735.508997    5807 buffer_comparator.cc:156] Difference at 11: 0.169067, expected 0
# 2025-04-14 18:45:35.509025: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[1,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,128,128,3]{3,2,1,0} %bitcast.108301, f16[64,3,3,3]{3,2,1,0} %bitcast.108307, f16[64]{0} %bitcast.108311, f16[1,126,126,64]{3,2,1,0} %bitcast.108326), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 18:45:35.509038: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 18:45:35.509041: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 18:45:35.509043: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 18:45:35.509045: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 18:45:35.509050: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.2127 - loss: 10.1912 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 43s 668ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 44s 681ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 44s 685ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 43s 675ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 44s 690ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 44s 686ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 43s 687ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 44s 688ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 43s 676ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 44s 689ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 43s 675ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 652ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 43s 665ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 654ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 641ms/step - accuracy: 0.3071 - loss: 11.1681 - val_accuracy: 0.1333 - val_loss: 13.9690

# %% [markdown]
# # **Evaluate the Trained Model**
# After training, we will evaluate the model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)
# Out:
# 2025-04-14 20:38:45.933200: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,126,126,64]{3,2,1,0} %bitcast.2851, f16[64,3,3,64]{3,2,1,0} %bitcast.2752), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:48.187332: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,126,126,64]{3,2,1,0} %bitcast.2851, f16[64,3,3,64]{3,2,1,0} %bitcast.2752), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:48.422910: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.60 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,126,126,64]{3,2,1,0} %bitcast.2851, f16[64,3,3,64]{3,2,1,0} %bitcast.2752), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744641532.697877    5804 buffer_comparator.cc:156] Difference at 0: 0.245972, expected -nan
# E0000 00:00:1744641532.698029    5804 buffer_comparator.cc:156] Difference at 1: 0.166504, expected 0
# E0000 00:00:1744641532.698036    5804 buffer_comparator.cc:156] Difference at 2: 0.182251, expected -nan
# E0000 00:00:1744641532.698039    5804 buffer_comparator.cc:156] Difference at 3: 0.162231, expected 0
# E0000 00:00:1744641532.698041    5804 buffer_comparator.cc:156] Difference at 4: 0.175049, expected -nan
# E0000 00:00:1744641532.698042    5804 buffer_comparator.cc:156] Difference at 5: 0.190796, expected 0
# E0000 00:00:1744641532.698044    5804 buffer_comparator.cc:156] Difference at 6: 0.174438, expected -nan
# E0000 00:00:1744641532.698046    5804 buffer_comparator.cc:156] Difference at 7: 0.192993, expected 0
# E0000 00:00:1744641532.698048    5804 buffer_comparator.cc:156] Difference at 8: 0.219604, expected -nan
# E0000 00:00:1744641532.698050    5804 buffer_comparator.cc:156] Difference at 9: 0.207153, expected 0
# 2025-04-14 20:38:52.698510: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.100 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,128,128,3]{3,2,1,0} %bitcast.2734, f16[64,3,3,3]{3,2,1,0} %bitcast.2740, f16[64]{0} %bitcast.2744, f16[32,126,126,64]{3,2,1,0} %bitcast.2756), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 20:38:52.698530: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:52.698533: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:52.698537: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:52.698538: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:52.698552: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641532.871359    5804 buffer_comparator.cc:156] Difference at 0: 0.245972, expected -nan
# E0000 00:00:1744641532.871424    5804 buffer_comparator.cc:156] Difference at 1: 0.166504, expected 0
# E0000 00:00:1744641532.871429    5804 buffer_comparator.cc:156] Difference at 2: 0.182251, expected -nan
# E0000 00:00:1744641532.871431    5804 buffer_comparator.cc:156] Difference at 3: 0.162231, expected 0
# E0000 00:00:1744641532.871433    5804 buffer_comparator.cc:156] Difference at 4: 0.175049, expected -nan
# E0000 00:00:1744641532.871435    5804 buffer_comparator.cc:156] Difference at 5: 0.190796, expected 0
# E0000 00:00:1744641532.871438    5804 buffer_comparator.cc:156] Difference at 6: 0.174438, expected -nan
# E0000 00:00:1744641532.871439    5804 buffer_comparator.cc:156] Difference at 7: 0.192993, expected 0
# E0000 00:00:1744641532.871441    5804 buffer_comparator.cc:156] Difference at 8: 0.219604, expected -nan
# E0000 00:00:1744641532.871443    5804 buffer_comparator.cc:156] Difference at 9: 0.207153, expected 0
# 2025-04-14 20:38:52.871960: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.100 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,128,128,3]{3,2,1,0} %bitcast.2734, f16[64,3,3,3]{3,2,1,0} %bitcast.2740, f16[64]{0} %bitcast.2744, f16[32,126,126,64]{3,2,1,0} %bitcast.2756), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 20:38:52.871994: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:52.871999: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:52.872003: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:52.872005: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:52.872018: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641533.467726    5804 buffer_comparator.cc:156] Difference at 0: 0.245972, expected -nan
# E0000 00:00:1744641533.467788    5804 buffer_comparator.cc:156] Difference at 1: 0.166504, expected 0
# E0000 00:00:1744641533.467793    5804 buffer_comparator.cc:156] Difference at 2: 0.182251, expected -nan
# E0000 00:00:1744641533.467795    5804 buffer_comparator.cc:156] Difference at 3: 0.162231, expected 0
# E0000 00:00:1744641533.467797    5804 buffer_comparator.cc:156] Difference at 4: 0.175049, expected -nan
# E0000 00:00:1744641533.467799    5804 buffer_comparator.cc:156] Difference at 5: 0.190796, expected 0
# E0000 00:00:1744641533.467801    5804 buffer_comparator.cc:156] Difference at 6: 0.174438, expected -nan
# E0000 00:00:1744641533.467803    5804 buffer_comparator.cc:156] Difference at 7: 0.192993, expected 0
# E0000 00:00:1744641533.467805    5804 buffer_comparator.cc:156] Difference at 8: 0.219604, expected -nan
# E0000 00:00:1744641533.467807    5804 buffer_comparator.cc:156] Difference at 9: 0.207153, expected 0
# 2025-04-14 20:38:53.468183: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.100 = (f16[32,126,126,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,128,128,3]{3,2,1,0} %bitcast.2734, f16[64,3,3,3]{3,2,1,0} %bitcast.2740, f16[64]{0} %bitcast.2744, f16[32,126,126,64]{3,2,1,0} %bitcast.2756), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng31{k2=2,k6=0,k13=2,k14=0,k22=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 20:38:53.468211: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:53.468215: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:53.468219: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:53.468220: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:53.468232: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 20:38:54.157635: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.64 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,61,61,128]{3,2,1,0} %bitcast.3026, f16[128,3,3,128]{3,2,1,0} %bitcast.2927), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:54.272301: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.64 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,61,61,128]{3,2,1,0} %bitcast.3026, f16[128,3,3,128]{3,2,1,0} %bitcast.2927), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:38:54.386692: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.64 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,61,61,128]{3,2,1,0} %bitcast.3026, f16[128,3,3,128]{3,2,1,0} %bitcast.2927), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744641538.188327    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.188389    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.188394    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.188396    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.188398    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.188400    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.188402    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.188403    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.188406    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.188408    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.188773: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=0,k13=1,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:58.188801: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.188804: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.188807: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.188808: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.188821: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.269831    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.269893    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.269898    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.269900    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.269902    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.269904    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.269905    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.269908    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.269910    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.269912    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.270189: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=3,k13=0,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:58.270216: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.270219: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.270222: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.270223: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.270233: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.347484    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.347545    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.347549    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.347551    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.347553    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.347555    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.347557    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.347558    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.347560    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.347562    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.347869: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=0,k13=0,k14=0,k18=0,k23=0}
# 2025-04-14 20:38:58.347896: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.347899: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.347902: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.347903: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.347914: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.487011    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.487079    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.487084    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.487085    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.487087    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.487089    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.487091    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.487093    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.487095    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.487097    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.487405: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=0,k13=0,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:58.487450: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.487455: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.487459: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.487461: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.487473: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.624913    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.624980    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.624984    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.624986    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.624988    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.624990    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.624991    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.624993    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.624996    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.624998    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.625320: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=4,k13=0,k14=0,k18=0,k23=0}
# 2025-04-14 20:38:58.625349: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.625352: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.625355: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.625357: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.625369: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.724158    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.724206    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.724210    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.724212    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.724214    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.724216    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.724218    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.724219    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.724221    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.724223    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.724460: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=4,k13=0,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:58.724474: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.724476: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.724480: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.724482: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.724493: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.825327    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.825391    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.825396    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.825399    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.825401    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.825402    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.825404    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.825406    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.825408    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.825409    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.825643: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=1,k13=0,k14=0,k18=0,k23=0}
# 2025-04-14 20:38:58.825674: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.825677: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.825680: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.825682: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.825694: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641538.945722    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641538.945777    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641538.945781    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641538.945783    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641538.945785    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641538.945787    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641538.945789    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641538.945791    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641538.945793    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641538.945795    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:58.946060: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng8{k2=0,k13=0,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:58.946083: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:58.946086: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:58.946090: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:58.946093: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:58.946107: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.045995    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.046060    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.046064    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.046066    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.046068    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.046070    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.046072    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.046074    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.046076    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.046079    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.046305: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=5,k13=1,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:59.046333: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.046336: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.046339: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.046340: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.046350: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.124558    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.124620    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.124625    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.124627    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.124628    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.124632    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.124634    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.124635    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.124637    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.124639    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.124852: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng9{k2=5,k13=1,k14=0,k18=1,k23=0}
# 2025-04-14 20:38:59.124879: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.124882: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.124885: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.124887: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.124897: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.244279    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.244346    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.244350    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.244352    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.244354    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.244356    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.244358    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.244359    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.244362    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.244364    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.244596: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng8{k2=4,k13=0,k14=0,k18=0,k23=2}
# 2025-04-14 20:38:59.244613: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.244615: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.244618: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.244621: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.244632: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.333010    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.333089    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.333094    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.333096    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.333099    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.333100    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.333102    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.333106    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# E0000 00:00:1744641539.333108    5804 buffer_comparator.cc:156] Difference at 8: -nan, expected 1.68262
# E0000 00:00:1744641539.333110    5804 buffer_comparator.cc:156] Difference at 9: 0, expected 1.67773
# 2025-04-14 20:38:59.333438: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.104 = (f16[32,61,61,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,63,63,64]{3,2,1,0} %bitcast.2909, f16[128,3,3,64]{3,2,1,0} %bitcast.2915, f16[128]{0} %bitcast.2919, f16[32,61,61,128]{3,2,1,0} %bitcast.2931), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_1_2/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng4{k2=3,k4=2,k5=3,k6=3,k7=2} vs eng31{k2=2,k6=3,k13=1,k14=0,k22=2}
# 2025-04-14 20:38:59.333491: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:38:59.333496: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:38:59.333501: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:38:59.333503: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:38:59.333517: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641539.422644    5804 buffer_comparator.cc:156] Difference at 0: -nan, expected 1.54102
# E0000 00:00:1744641539.422766    5804 buffer_comparator.cc:156] Difference at 1: 0, expected 1.68262
# E0000 00:00:1744641539.422786    5804 buffer_comparator.cc:156] Difference at 2: -nan, expected 1.69336
# E0000 00:00:1744641539.422789    5804 buffer_comparator.cc:156] Difference at 3: 0, expected 1.56641
# E0000 00:00:1744641539.422791    5804 buffer_comparator.cc:156] Difference at 4: -nan, expected 1.63867
# E0000 00:00:1744641539.422793    5804 buffer_comparator.cc:156] Difference at 5: 0, expected 1.69336
# E0000 00:00:1744641539.422795    5804 buffer_comparator.cc:156] Difference at 6: -nan, expected 1.74023
# E0000 00:00:1744641539.422797    5804 buffer_comparator.cc:156] Difference at 7: 0, expected 1.4873
# ...
# E0000 00:00:1744641567.485964    5803 buffer_comparator.cc:156] Difference at 7: 3.18359, expected 0
# E0000 00:00:1744641567.485967    5803 buffer_comparator.cc:156] Difference at 8: 3.06055, expected -nan
# E0000 00:00:1744641567.485969    5803 buffer_comparator.cc:156] Difference at 9: 3.04297, expected 0
# 2025-04-14 20:39:27.485989: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.112 = (f16[16,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,15,15,128]{3,2,1,0} %bitcast.3259, f16[256,3,3,128]{3,2,1,0} %bitcast.3265, f16[256]{0} %bitcast.3269, f16[16,13,13,256]{3,2,1,0} %bitcast.3281), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng9{k2=0,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 20:39:27.486002: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:27.486005: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:27.486007: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:27.486009: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:27.486015: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641567.508763    5803 buffer_comparator.cc:156] Difference at 0: 3.11523, expected -nan
# E0000 00:00:1744641567.508828    5803 buffer_comparator.cc:156] Difference at 1: 3.11719, expected 0
# E0000 00:00:1744641567.508832    5803 buffer_comparator.cc:156] Difference at 2: 3.08203, expected -nan
# E0000 00:00:1744641567.508835    5803 buffer_comparator.cc:156] Difference at 3: 2.97852, expected 0
# E0000 00:00:1744641567.508836    5803 buffer_comparator.cc:156] Difference at 4: 3.10938, expected -nan
# E0000 00:00:1744641567.508838    5803 buffer_comparator.cc:156] Difference at 5: 3.20117, expected 0
# E0000 00:00:1744641567.508840    5803 buffer_comparator.cc:156] Difference at 6: 3.05859, expected -nan
# E0000 00:00:1744641567.508842    5803 buffer_comparator.cc:156] Difference at 7: 3.18359, expected 0
# E0000 00:00:1744641567.508846    5803 buffer_comparator.cc:156] Difference at 8: 3.06055, expected -nan
# E0000 00:00:1744641567.508848    5803 buffer_comparator.cc:156] Difference at 9: 3.04297, expected 0
# 2025-04-14 20:39:27.508870: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.112 = (f16[16,13,13,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,15,15,128]{3,2,1,0} %bitcast.3259, f16[256,3,3,128]{3,2,1,0} %bitcast.3265, f16[256]{0} %bitcast.3269, f16[16,13,13,256]{3,2,1,0} %bitcast.3281), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_3_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng9{k2=0,k13=1,k14=0,k18=0,k23=2} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 20:39:27.508884: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:27.508886: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:27.508888: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:27.508890: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:27.508898: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2025-04-14 20:39:27.871976: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=4,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,5,5,512]{3,2,1,0} %bitcast.3551, f16[512,3,3,512]{3,2,1,0} %bitcast.3452), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:39:28.078621: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=0,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,5,5,512]{3,2,1,0} %bitcast.3551, f16[512,3,3,512]{3,2,1,0} %bitcast.3452), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-04-14 20:39:28.179015: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv.76 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,5,5,512]{3,2,1,0} %bitcast.3551, f16[512,3,3,512]{3,2,1,0} %bitcast.3452), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_7" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# E0000 00:00:1744641568.594377    5803 buffer_comparator.cc:156] Difference at 0: 5.97656, expected -nan
# E0000 00:00:1744641568.594430    5803 buffer_comparator.cc:156] Difference at 1: 6.03516, expected 0
# E0000 00:00:1744641568.594435    5803 buffer_comparator.cc:156] Difference at 2: 6.10938, expected -nan
# E0000 00:00:1744641568.594437    5803 buffer_comparator.cc:156] Difference at 3: 5.94531, expected 0
# E0000 00:00:1744641568.594439    5803 buffer_comparator.cc:156] Difference at 4: 5.87891, expected -nan
# E0000 00:00:1744641568.594442    5803 buffer_comparator.cc:156] Difference at 5: 5.99609, expected 0
# E0000 00:00:1744641568.594443    5803 buffer_comparator.cc:156] Difference at 6: 5.99609, expected -nan
# E0000 00:00:1744641568.594445    5803 buffer_comparator.cc:156] Difference at 7: 5.96484, expected 0
# E0000 00:00:1744641568.594447    5803 buffer_comparator.cc:156] Difference at 8: 5.76562, expected -nan
# E0000 00:00:1744641568.594449    5803 buffer_comparator.cc:156] Difference at 9: 5.99609, expected 0
# 2025-04-14 20:39:28.594466: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,7,7,256]{3,2,1,0} %bitcast.3434, f16[512,3,3,256]{3,2,1,0} %bitcast.3440, f16[512]{0} %bitcast.3444, f16[16,5,5,512]{3,2,1,0} %bitcast.3456), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng22{k2=5,k12=5,k13=1,k14=0,k15=0,k17=43,k18=1,k23=0} vs eng4{k2=4,k4=1,k5=4,k6=3,k7=2}
# 2025-04-14 20:39:28.594478: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:28.594481: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:28.594483: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:28.594485: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:28.594490: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641568.635014    5803 buffer_comparator.cc:156] Difference at 0: 5.97656, expected -nan
# E0000 00:00:1744641568.635067    5803 buffer_comparator.cc:156] Difference at 1: 6.03516, expected 0
# E0000 00:00:1744641568.635072    5803 buffer_comparator.cc:156] Difference at 2: 6.10938, expected -nan
# E0000 00:00:1744641568.635074    5803 buffer_comparator.cc:156] Difference at 3: 5.94531, expected 0
# E0000 00:00:1744641568.635076    5803 buffer_comparator.cc:156] Difference at 4: 5.87891, expected -nan
# E0000 00:00:1744641568.635078    5803 buffer_comparator.cc:156] Difference at 5: 5.99609, expected 0
# E0000 00:00:1744641568.635081    5803 buffer_comparator.cc:156] Difference at 6: 5.99609, expected -nan
# E0000 00:00:1744641568.635083    5803 buffer_comparator.cc:156] Difference at 7: 5.96484, expected 0
# E0000 00:00:1744641568.635084    5803 buffer_comparator.cc:156] Difference at 8: 5.76562, expected -nan
# E0000 00:00:1744641568.635086    5803 buffer_comparator.cc:156] Difference at 9: 5.99609, expected 0
# 2025-04-14 20:39:28.635104: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,7,7,256]{3,2,1,0} %bitcast.3434, f16[512,3,3,256]{3,2,1,0} %bitcast.3440, f16[512]{0} %bitcast.3444, f16[16,5,5,512]{3,2,1,0} %bitcast.3456), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng22{k2=5,k12=5,k13=1,k14=0,k15=0,k17=43,k18=1,k23=0} vs eng4{k2=0,k4=1,k5=3,k6=3,k7=2}
# 2025-04-14 20:39:28.635118: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:28.635121: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:28.635124: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:28.635125: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:28.635130: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# E0000 00:00:1744641568.772768    5803 buffer_comparator.cc:156] Difference at 0: 5.97656, expected -nan
# E0000 00:00:1744641568.772823    5803 buffer_comparator.cc:156] Difference at 1: 6.03516, expected 0
# E0000 00:00:1744641568.772828    5803 buffer_comparator.cc:156] Difference at 2: 6.10938, expected -nan
# E0000 00:00:1744641568.772830    5803 buffer_comparator.cc:156] Difference at 3: 5.94531, expected 0
# E0000 00:00:1744641568.772832    5803 buffer_comparator.cc:156] Difference at 4: 5.87891, expected -nan
# E0000 00:00:1744641568.772833    5803 buffer_comparator.cc:156] Difference at 5: 5.99609, expected 0
# E0000 00:00:1744641568.772836    5803 buffer_comparator.cc:156] Difference at 6: 5.99609, expected -nan
# E0000 00:00:1744641568.772837    5803 buffer_comparator.cc:156] Difference at 7: 5.96484, expected 0
# E0000 00:00:1744641568.772839    5803 buffer_comparator.cc:156] Difference at 8: 5.76562, expected -nan
# E0000 00:00:1744641568.772841    5803 buffer_comparator.cc:156] Difference at 9: 5.99609, expected 0
# 2025-04-14 20:39:28.772860: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bias-activation.116 = (f16[16,5,5,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,7,7,256]{3,2,1,0} %bitcast.3434, f16[512,3,3,256]{3,2,1,0} %bitcast.3440, f16[512]{0} %bitcast.3444, f16[16,5,5,512]{3,2,1,0} %bitcast.3456), window={size=3x3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="sequential_1/conv_lstm2d_4_1/while/conv_lstm_cell_1/convolution_3" source_file="/mnt/h/Study/Academic/Part 4/Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":1,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng22{k2=5,k12=5,k13=1,k14=0,k15=0,k17=43,k18=1,k23=0} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# 2025-04-14 20:39:28.772874: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA GeForce GTX 1660 Ti
# 2025-04-14 20:39:28.772877: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 7.5
# 2025-04-14 20:39:28.772880: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 12.6.0
# 2025-04-14 20:39:28.772881: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.8.0
# 2025-04-14 20:39:28.772887: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.8.0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 17s/step - accuracy: 0.2257 - loss: 12.4803

# %% [markdown]
# # **Save the Model**
# Now, we will save the model to avoid training it from scratch every time we need the model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.keras'

# Save the Model.
convlstm_model.save(model_file_name)

# %% [markdown]
# ### Load the saved Model

# %%
convlstm_model = tf.keras.models.load_model('convlstm_model___Date_Time_2025_03_25__23_43_26___Loss_0.5146016478538513___Accuracy_0.8333333134651184.keras')

# %% [markdown]
# # **Step 4.3: Plot Model's Loss & Accuracy Curves**
# Now, we will create a function `plot_metric()` to visualize the training and validation metrics. We already have separate metrics from our training and validation steps so now we just have to visualize them.

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):

  '''
  This function will plot the metrics passed to it in a graph.

  Args:

    model_training_history: A history object containing a record of training and validation loss values and metrics values at successive epochs.
    metric_name_1:          The name of the first metric that needs to be plotted in the graph.
    metric_name_2:          The name of the second metric that needs to be plotted in the graph.
    plot_name:              The title of the graph.

  '''

  # Get metric values using metric names as identifiers.
  metric_value_1 = model_training_history.history[metric_name_1]
  metric_value_2 = model_training_history.history[metric_name_2]

  # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
  epochs = range(len(metric_value_1))

  # Plot the graph
  plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
  plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

  # Add title to the plot
  plt.title(str(plot_name))

  # Add legend to the plot.
  plt.legend()

# %% [markdown]
# Now we will utilize the function `plot_metric()` created above, to visualize and understand the metrics.

# %%
# Visualize the training and validation loss metrics.
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrics.
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# # **Step 5: Implement The LRCN Approach**
#
# In this step, we will implement the LRCN approach by combining Convolution and LSTM layers in a single model. Another similar approach can be to use a CNN model and LSTM model trained separately.
#
# The CNN model can be used to extract spatial features from the frames in the video, and for this purpose, a pre-trained model can be used, that can be fine-tuned for the problem. And the LSTM model can then use the features extracted by CNN, to predict the action being performed in the video.
#
# But here, we will implement another approach known as the `Long-term Recurrent Convolutional Network (LRCN)`, which combines CNN and LSTM layers in a single model. The Convolutional layers are used for spatial features extraction from the frames, and the extracted spatial features are fed to LSTM layes at each time-steps for temporal sequence modeling. This way the network learns spatiotemporal features directly in an end-to-end training, resulting in a robust model.

# %% [markdown]
# # **Step 5.1: Construct the Model**
#
# To implement our LRCN architecture, we will use time-distributed `Conv2D` layers which will be followed by `MaxPooling2D` and `Dropout` layers. The feature extracted from the `Conv2D` layers will be then flattened using the `Flatten` layer and will be fed to a `LSTM` layer. The `Dense` layer with `softmax` activation will then use the output from the `LSTM` layer to predict the action being performed.

# %%
def create_LRCN_model():
  '''
  This function will construct the required LRCN model.

  Returns:
    model: It is the required constructed LRCN model.

  '''

  # We will use a Sequencial model for model construction.
  model = Sequential()

  # Define the Model Architecture.

  model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'), input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

  model.add(TimeDistributed(MaxPooling2D((4, 4))))
  model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((4, 4))))
  model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((2, 2))))
  model.add(TimeDistributed(Dropout(0.25)))
  
  model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((2, 2))))
  model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',activation = 'relu')))
  model.add(TimeDistributed(MaxPooling2D((2, 2))))
  #model.add(TimeDistributed(Dropout(0.25)))

  model.add(TimeDistributed(Flatten()))

  model.add(LSTM(32))

  # Use Bidirectional LSTM here instead of normal LSTM
  #model.add(Bidirectional(LSTM(32)))

  model.add(Dense(len(CLASSES_LIST), activation = "softmax"))

  # Display the models summary.
  model.summary()

  # Return the constructed LRCN model.
  return model

# %% [markdown]
# Now we will utilize the function `create_LRCN_model()` created above to construct the required LRCN model.

# %%
# Construct the required LRCN model
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!!")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_15             │ (None, 10, 128, 128,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 10, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 10, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_18             │ (None, 10, 32, 32, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_19             │ (None, 10, 8, 8, 32)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_20             │ (None, 10, 8, 8, 32)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_21             │ (None, 10, 8, 8, 64)   │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_22             │ (None, 10, 4, 4, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_23             │ (None, 10, 4, 4, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_24             │ (None, 10, 4, 4, 64)   │        36,928 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_25             │ (None, 10, 2, 2, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_26             │ (None, 10, 2, 2, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_27             │ (None, 10, 2, 2, 128)  │        73,856 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_28             │ (None, 10, 1, 1, 128)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_29             │ (None, 10, 128)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 155,108 (605.89 KB)
#  Trainable params: 155,108 (605.89 KB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!!

# %% [markdown]
# # **Check Model's Structure**
# Now we will use the `plot_model()` function to check the structure of the constructed `LRCN` model. As we had checked for the previous model.

# %%
# Plot the structure of the constructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # **Step 5.2: Compile & Train the Model**
#
# After checking the structure, we will compile and start training the model.

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 20, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4, shuffle = True, validation_split = 0.05, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 2025-03-28 16:59:30.926557: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 263454720 exceeds 10% of free system memory.
# 2025-03-28 16:59:31.190183: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 263454720 exceeds 10% of free system memory.
# I0000 00:00:1743159578.406720    4688 cuda_dnn.cc:529] Loaded cuDNN version 90800
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.4977 - loss: 1.2776 - val_accuracy: 0.1250 - val_loss: 1.6470
# Epoch 2/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.5570 - loss: 1.1289 - val_accuracy: 0.1250 - val_loss: 1.7015
# Epoch 3/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.5570 - loss: 1.1026 - val_accuracy: 0.1250 - val_loss: 1.6399
# Epoch 4/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6030 - loss: 1.0241 - val_accuracy: 0.1250 - val_loss: 1.7997
# Epoch 5/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6704 - loss: 0.9546 - val_accuracy: 0.1250 - val_loss: 1.7359
# Epoch 6/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6992 - loss: 0.8459 - val_accuracy: 0.2500 - val_loss: 1.3896
# Epoch 7/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6974 - loss: 0.8740 - val_accuracy: 0.1250 - val_loss: 1.8961
# Epoch 8/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6624 - loss: 0.8626 - val_accuracy: 0.1250 - val_loss: 1.7447
# Epoch 9/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7119 - loss: 0.8064 - val_accuracy: 0.2500 - val_loss: 1.4599
# Epoch 10/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7217 - loss: 0.7468 - val_accuracy: 0.2500 - val_loss: 1.3578
# Epoch 11/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7349 - loss: 0.7047 - val_accuracy: 0.2500 - val_loss: 1.2564
# Epoch 12/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6827 - loss: 0.6969 - val_accuracy: 0.3750 - val_loss: 1.2443
# Epoch 13/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7940 - loss: 0.6517 - val_accuracy: 0.2500 - val_loss: 1.9631
# Epoch 14/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7835 - loss: 0.6263 - val_accuracy: 0.5000 - val_loss: 1.1467
# Epoch 15/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7960 - loss: 0.6081 - val_accuracy: 0.3750 - val_loss: 1.2257
# Epoch 16/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.7431 - loss: 0.5874 - val_accuracy: 0.3750 - val_loss: 1.3924
# Epoch 17/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7254 - loss: 0.6691 - val_accuracy: 0.3750 - val_loss: 1.1992
# Epoch 18/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7862 - loss: 0.5586 - val_accuracy: 0.3750 - val_loss: 1.2469
# Epoch 19/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7893 - loss: 0.5422 - val_accuracy: 0.5000 - val_loss: 1.0130
# Epoch 20/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8003 - loss: 0.5194 - val_accuracy: 0.3750 - val_loss: 1.2567
# Epoch 21/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7993 - loss: 0.4594 - val_accuracy: 0.3750 - val_loss: 1.1271
# Epoch 22/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8173 - loss: 0.4159 - val_accuracy: 0.5000 - val_loss: 0.9344
# Epoch 23/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8037 - loss: 0.4772 - val_accuracy: 0.6250 - val_loss: 1.2410
# Epoch 24/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8510 - loss: 0.4261 - val_accuracy: 0.3750 - val_loss: 1.1814
# Epoch 25/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8607 - loss: 0.3700 - val_accuracy: 0.5000 - val_loss: 1.5714
# Epoch 26/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8344 - loss: 0.3678 - val_accuracy: 0.6250 - val_loss: 1.0902
# Epoch 27/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8413 - loss: 0.3580 - val_accuracy: 0.5000 - val_loss: 1.1057
# Epoch 28/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8658 - loss: 0.3084 - val_accuracy: 0.7500 - val_loss: 1.0154
# Epoch 29/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8610 - loss: 0.3103 - val_accuracy: 0.7500 - val_loss: 1.3083
# Epoch 30/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8764 - loss: 0.2925 - val_accuracy: 0.7500 - val_loss: 1.0936
# Epoch 31/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8818 - loss: 0.2602 - val_accuracy: 0.6250 - val_loss: 1.5490
# Epoch 32/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9054 - loss: 0.2520 - val_accuracy: 0.7500 - val_loss: 0.8594
# Epoch 33/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8678 - loss: 0.2732 - val_accuracy: 0.7500 - val_loss: 1.1596
# Epoch 34/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9339 - loss: 0.1935 - val_accuracy: 0.6250 - val_loss: 1.0487
# Epoch 35/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8871 - loss: 0.2047 - val_accuracy: 0.6250 - val_loss: 1.1431
# Epoch 36/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9243 - loss: 0.1978 - val_accuracy: 0.6250 - val_loss: 1.1965
# Epoch 37/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9259 - loss: 0.1979 - val_accuracy: 0.6250 - val_loss: 1.3976
# Epoch 38/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9234 - loss: 0.2349 - val_accuracy: 0.6250 - val_loss: 1.1074
# Epoch 39/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9344 - loss: 0.1964 - val_accuracy: 0.5000 - val_loss: 1.2986
# Epoch 40/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9248 - loss: 0.2110 - val_accuracy: 0.7500 - val_loss: 0.9392
# Epoch 41/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9540 - loss: 0.1593 - val_accuracy: 0.7500 - val_loss: 0.8242
# Epoch 42/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9260 - loss: 0.2037 - val_accuracy: 0.6250 - val_loss: 1.6979
# Epoch 43/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.7672 - loss: 0.5791 - val_accuracy: 0.7500 - val_loss: 1.0092
# Epoch 44/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9753 - loss: 0.1342 - val_accuracy: 0.6250 - val_loss: 1.6093
# Epoch 45/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9352 - loss: 0.1564 - val_accuracy: 0.6250 - val_loss: 1.6544
# Epoch 46/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9321 - loss: 0.1573 - val_accuracy: 0.5000 - val_loss: 2.2593
# Epoch 47/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9590 - loss: 0.1169 - val_accuracy: 0.5000 - val_loss: 1.9410
# Epoch 48/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9612 - loss: 0.0913 - val_accuracy: 0.5000 - val_loss: 1.8948
# Epoch 49/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9665 - loss: 0.0804 - val_accuracy: 0.3750 - val_loss: 1.7003
# Epoch 50/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9656 - loss: 0.0779 - val_accuracy: 0.5000 - val_loss: 1.9158
# Epoch 51/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9787 - loss: 0.0624 - val_accuracy: 0.5000 - val_loss: 1.6015
# Epoch 52/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9895 - loss: 0.0398 - val_accuracy: 0.5000 - val_loss: 2.1015
# Epoch 53/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.9527 - loss: 0.1580 - val_accuracy: 0.5000 - val_loss: 1.8064
# Epoch 54/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9603 - loss: 0.1583 - val_accuracy: 0.5000 - val_loss: 1.6525
# Epoch 55/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9579 - loss: 0.1059 - val_accuracy: 0.5000 - val_loss: 2.0059
# Epoch 56/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9908 - loss: 0.0619 - val_accuracy: 0.5000 - val_loss: 1.6351
# Epoch 57/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 0.5000 - val_loss: 2.4614
# Epoch 58/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9810 - loss: 0.0485 - val_accuracy: 0.5000 - val_loss: 1.9222
# Epoch 59/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9743 - loss: 0.0550 - val_accuracy: 0.5000 - val_loss: 1.6795
# Epoch 60/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9697 - loss: 0.0632 - val_accuracy: 0.5000 - val_loss: 1.9066
# Epoch 61/70
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9801 - loss: 0.0408 - val_accuracy: 0.3750 - val_loss: 2.1622

# %% [markdown]
# # **Evaluating the Trained Model**
#
# As done for previous one, we will evaluate the `LRCN` model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 665ms/step - accuracy: 0.7604 - loss: 0.6449

# %% [markdown]
# # **Save the Model**
# After that, we will save the model for future uses using the same technique we had used for previous model.

# %%
# Get the loss and accuracy from mode_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'multiclass_LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.keras'

# Save the Model.
LRCN_model.save(model_file_name)

# %% [markdown]
# ### Load the saved model

# %%
LRCN_model = tf.keras.models.load_model('LRCN_model___Date_Time_2025_03_27__02_14_17___Loss_0.44080331921577454___Accuracy_0.7708333134651184.keras')
# Out:
# I0000 00:00:1743022550.473532     739 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:10:00.0, compute capability: 7.5

# %% [markdown]
# # **Step 5.3: Plot Model's Loss & Accuracy Curves**
#
# Now we will utilize the function `plot_metric()` we had created above to visualize the training and validation metrics of this model.

# %%
# Visualize the training and validation loss matrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Visualize the training and validation loss matrices.
# ----> 2 plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')
#
# NameError: name 'plot_metric' is not defined

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Visualize the training and validation accuracy metrices.
# ----> 2 plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
#
# NameError: name 'plot_metric' is not defined

# %% [markdown]
# # **Step 6: Test the Best Performing Model on YouTube videos**

# %% [markdown]
# # **Create a Function to Download YouTube Videos**
#
# We will create a function `download_youtube_videos()` to download the YouTube videos first using `pafy` library. The library only requires a URL to a video to download it along with its associated metadata like the title of the video.

# %%
pafy.set_backend("yt_dlp")
def download_youtube_videos(youtube_video_url, output_directory):
    """
    This function downloads the YouTube video whose URL is passed to it as an argument.

    Args:
        youtube_video_url: URL of the video that is required to be downloaded.
        output_directory: The directory path to which the video needs to be stored after downloading.

    Returns:
        title: The title of the downloaded YouTube video.
    """

    # Create a video object which contains useful information about the video.
    video = pafy.new(youtube_video_url)

    # Retrieve the title of the video.
    title = video.title

    # Get the best available quality object for the video.
    video_best = video.getbest()

    # Construct the output file path.
    output_file_path = f'{output_directory}/{title}.mp4'

    # Download the YouTube video at the best available quality and store it to the constructed path.
    video_best.download(filepath=output_file_path, quiet=True)

    # Return the video title.
    return title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-107331fd889a> in <cell line: 0>()
# ----> 1 pafy.set_backend("yt_dlp")
#       2 def download_youtube_videos(youtube_video_url, output_directory):
#       3     """
#       4     This function downloads the YouTube video whose URL is passed to it as an argument.
#       5
#
# AttributeError: module 'pafy' has no attribute 'set_backend'

# %% [markdown]
# # **Download a Test Video**
#
# Now we will utilize the function `download_youtube_videos()` created above to download a youtube video on which the LRCN model will be tested.

# %%
# Make the Output directory if it does not exist
test_videos_directory = 'test_videos'
os.makedirs(test_videos_directory, exist_ok = True)

# Download a YouTube Video.
#video_title = download_youtube_videos('https://www.youtube.com/watch?v=mzelalrFNRk', test_videos_directory)
video_title = "test_video_1"

# Get the YouTube Video's path we just downloaded.
input_video_file_path = f'{test_videos_directory}/{video_title}.mp4'

# %% [markdown]
# # **Download The Model**

# %%
from google.colab import files

# Download the file
#files.download("convlstm_model___Date_Time_2025_01_18__17_14_01___Loss_0.2780801057815552___Accuracy_0.9027777910232544.keras")
files.download("LRCN_model___Date_Time_2025_01_18__18_17_00___Loss_0.28902676701545715___Accuracy_0.8819444179534912.keras")

# %% [markdown]
# # **Create a Function to perform Action Recognition on Videos**
#
# Next, we will create a function `predict_on_video()` that will simply read a video frame by frame from the path passed in as an argument and will perform action recognition on video and save the results.

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH, Loaded_Model):
    """
    This function will perform action recognition on a video using the LRCN model.
    Args:
        video_file_path: The path of the video file in the disk which action recognition is to be performed.
        output_file_path: The file where the corresponding prediction for the actions performed on each frame will be stored.
        SEQUENCE_LENGTH: Fixed number of frames in a video that can be fed to the model as one sequence.
    """

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_width = int(video_reader.get(cv.CAP_PROP_FRAME_WIDTH))
    original_height = int(video_reader.get(cv.CAP_PROP_FRAME_HEIGHT))

    # Initialize the VideoWriter object to store the output video in the disk.
    video_writer = cv.VideoWriter(output_file_path, cv.VideoWriter_fourcc('M', 'P', '4', 'V'), video_reader.get(cv.CAP_PROP_FPS), (original_width, original_height))

    # Declare a queue to store video frames.
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)

    # Define a queue to store video frames
    frames_queue = deque(maxlen=SEQUENCE_LENGTH)

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    while video_reader.isOpened():

      # Read the frame.
      ok, frame = video_reader.read()

      # Check if frame is not read properly then break the loop
      if not ok:
        break

      # Resize the Frame to fixed Dimensions.
      resized_frame = cv.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

      # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
      normalized_frame = resized_frame / 255

      # Appending the pre-processed frame into the frames list.
      frames_queue.append(normalized_frame)

      # Check if the number of frame in the queue are equal to the fixed sequence length.
      if len(frames_queue) == SEQUENCE_LENGTH:

        # Pass the normalized frames to the model and get the predicted probabilities.
        predicted_label_probabilities = Loaded_Model.predict(np.expand_dims(frames_queue, axis = 0))[0]

        # Get the index of class with highest probability.
        predicted_label = np.argmax(predicted_label_probabilities)

        # Get the class name using the retrieved index.
        predicted_class_name = CLASSES_LIST[predicted_label]
        
        if predicted_class_name == "accident":
          cv.putText(frame, "Abnormal Activity [ Accident ]", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        elif predicted_class_name == "fighting":
          cv.putText(frame, "Abnormal Activity [ Fighting ]", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        elif predicted_class_name == "fire":
          cv.putText(frame, "Abnormal Activity [ Fire ]", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        else:
          cv.putText(frame, "Normal Activity", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

      # Write predicted class name on top of the Frame.
      #cv.putText(frame, predicted_class_name, (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

      # Write The frame into the disk using the VideoWriter Object.
      video_writer.write(frame)

    # Release the VideoCapture and VideoWriter objects.
    video_reader.release()
    video_writer.release()

# %% [markdown]
# # **Perform Action Recognition on the Test Video**
#
# Now we will utilize the function `predict_on_video()` created above to perform action recognition on the test video we had downloaded using the function `download_youtube_videos()` and display the ouput video with the predicted action overlayed on it.

# %%
test_videos_directory = 'test/outputs--multiclass_LRCN_model___Date_Time_2025_03_28__17_03_16___Loss_0.6673833727836609___Accuracy_0.75'

for i in range (1, 9):

    video_title = f'tested_video_{i}'

    print(f'Performing Prediction On Video {i}')

    # Construct the output video path.
    output_video_path = f'{test_videos_directory}/{video_title}-Output-SeqLen{SEQUENCE_LENGTH}.mp4'

    input_video_file_path = f'test/inputs/test_{i}.mp4'

    Loaded_Model = LRCN_model
    #Loaded_Model = convlstm_model

    # Perform Action Recognition on the Test Video.
    predict_on_video(input_video_file_path, output_video_path, SEQUENCE_LENGTH, Loaded_Model)

    # Display the output video.
    #VideoFileClip(output_video_path, audio=False, target_resolution=(300,None)).ipython_display()
# Out:
# Performing Prediction On Video 1
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Performing Prediction On Video 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Performing Prediction On Video 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %% [markdown]
# # **Create a Function To Perform a Single Prediction on Videos**
#
# Now let's create a function that will perform a single prediction for the complete videos. We will extract evenly distributed `N (SEQUENCE_LENGTH)` frames from the entire video and pass them to the LRCN model. This approach is really usefull when we are working with videos containing only one activity as it saves unnecessary computations and time in that scenario.

# %%
def predict_single_action(video_file_path, SEQUENCE_LENGTH):
    """
    This function will perform single action recognition prediction on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    """

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv.CAP_PROP_FRAME_HEIGHT))

    # Declare a list to store video frames we will extract.
    frames_list = []

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after whice frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):

      # Set the current frame position of the video.
      video_reader.set(cv.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

      # Read a frame.
      success, frame = video_reader.read()

      # Check if frame is not read properly then break the loop
      if not success:
        break

      # Resize the Frame to fixed Dimensions.
      resized_frame = cv.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

      # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
      nomalized_frame = resized_frame / 255

      # Appending the pre-processed frame into the frame list
      frames_list.append(nomalized_frame)

    # Passing the pre-processed frames to the model and get the predicted probabilities.
    predicted_label_probabilities = LRCN_model.predict(np.expand_dims(frames_list, axis = 0))[0]

    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_label_probabilities)

    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]

    # Display the predicted action along with the prediction confidence.
    print(f'Action Required: {predicted_class_name}\nConfidence: {predicted_label_probabilities[predicted_label]}')

    # Release the VideoCapture object.
    video_reader.release()

# %% [markdown]
# # **Perform Single Prediction on a Test Video**
#
# Now we will utilize the function `predict_single_action()` created above to perform a single prediction on a complete youtube test video that we will download using the function `download_youtube_videos()` we had created above.

# %%
# Video file name
video_title = 'test_video_3'

# Construct the input youtube video path
input_video_file_path = f'{test_videos_directory}/{video_title}.avi'

# Perform Single Prediction on the Test Video.
predict_single_action(input_video_file_path, SEQUENCE_LENGTH)

# Display the input video.
#VideoFileClip(input_video_file_path, audio=False, target_resolution=(300,None)).ipython_display()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Action Required: RopeClimbing
# Confidence: 0.7695754766464233
